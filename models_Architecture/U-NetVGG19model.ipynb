# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG19

# %%
def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

# %%
def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

# %%
def build_vgg19_unet(input_shape, num_classes):
    """ Input """
    inputs = Input(input_shape)

    """ Pre-trained VGG19 Model """
    vgg19 = VGG19(include_top=False, weights="imagenet", input_tensor=inputs)

    """ Encoder """
    s1 = vgg19.get_layer("block1_conv2").output         ## (512 x 512)
    s2 = vgg19.get_layer("block2_conv2").output         ## (256 x 256)
    s3 = vgg19.get_layer("block3_conv4").output         ## (128 x 128)
    s4 = vgg19.get_layer("block4_conv4").output         ## (64 x 64)

    """ Bridge """
    b1 = vgg19.get_layer("block5_conv4").output         ## (32 x 32)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)                     ## (64 x 64)
    d2 = decoder_block(d1, s3, 256)                     ## (128 x 128)
    d3 = decoder_block(d2, s2, 128)                     ## (256 x 256)
    d4 = decoder_block(d3, s1, 64)                      ## (512 x 512)

    """ Output """
    outputs = Conv2D(num_classes, 1, padding="same", activation="softmax")(d4)

    model = Model(inputs, outputs, name="VGG19_U-Net")
    return model

# %%
input_shape = (256, 256, 3)
model = build_vgg19_unet(input_shape,4)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 2s 0us/step
# 80150528/80134624 [==============================] - 2s 0us/step
# Model: "VGG19_U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 256, 256, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 128, 128, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 128, 128, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 128, 128, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 64, 64, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 64, 64, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 64, 64, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 64, 64, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_conv4 (Conv2D)          (None, 64, 64, 256)  590080      ['block3_conv3[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 32, 32, 256)  0           ['block3_conv4[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 32, 32, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_conv4 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_conv3[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 16, 16, 512)  0           ['block4_conv4[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block5_conv2[0][0]']
#
#  block5_conv4 (Conv2D)          (None, 16, 16, 512)  2359808     ['block5_conv3[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 512)  1049088    ['block5_conv4[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'block4_conv4[0][0]']
#
#  conv2d (Conv2D)                (None, 32, 32, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 512)  2048       ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 512)  0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 512)  2359808     ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 256)  524544     ['activation_1[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'block3_conv4[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 256)  1179904     ['concatenate_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 12  131200     ['activation_3[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'block2_conv2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 12  512        ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  activation_4 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_4[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 12  147584      ['activation_4[0][0]']
#                                 8)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  activation_5 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_5[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 64  32832      ['activation_5[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'block1_conv2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 256, 256, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 256, 256, 64  256        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 256, 256, 64  36928       ['activation_6[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 256, 256, 64  256        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 256, 256, 4)  260         ['activation_7[0][0]']
#
# ==================================================================================================
# Total params: 31,172,228
# Trainable params: 31,168,388
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
import os

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision, Accuracy, IoU
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive_path = '/content/drive/MyDrive/PFA'

# %%
H = 256
W = 256

def create_dir(path):
    """Create a directory"""
    if not os.path.exists(path):
        os.mkdir(path)

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def load_data(path, split=0.2):

    images = sorted(glob(f"{path}/ROI/*.bmp"))
    masks = sorted(glob(f"{path}/label/*.bmp"))
    
    print(len(masks), len(images))

    train_x, valid_x = train_test_split(images, test_size=0.2, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=0.2, random_state=42)
    print(len(train_x), len(train_y), len(valid_x), len(valid_y))
   
    return (train_x, train_y), (valid_x, valid_y)

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = x / 255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode('utf-8')
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x[x == 255] = 0
    x[x == 223] = 1 #ZP
    x[x == 127] = 2 #TE
    x[x == 191] = 3 #ICM
    x[ x > 3] = 0
    x = x.astype(np.int32)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.int32])
    y = tf.one_hot(y, 4, dtype=tf.int32)
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 4])

    return x, y

def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.shuffle(buffer_size=5000)
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.repeat()
    dataset = dataset.prefetch(2)

    return dataset

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

"""Directory for storing files"""
create_dir("/content/drive/MyDrive/PFA/files_vgg19")

"""Hyperparameters"""
batch_size = 10
learning_rate = 1e-4
num_epochs = 30
model_path = os.path.join("/content/drive/MyDrive/PFA/files_vgg19", "model.h5")
csv_path = os.path.join("/content/drive/MyDrive/PFA/files_vgg19", "data.csv")

"""Dataset"""
dataset_path = os.path.join("/content/drive/MyDrive/PFA/new_data")
train_path = os.path.join(dataset_path, "train")

(train_x, train_y), (valid_x, valid_y) = load_data(train_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
test_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

"""Model"""

model = build_vgg19_unet((H, W, 3),4)
metrics = [dice_coef, iou, 'accuracy', Recall(), Precision()]
model.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate), metrics=metrics)

train_steps = len(train_x)//batch_size
valid_steps = len(valid_x)//batch_size

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-7, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=False)
]

history = model.fit(
    train_dataset,
    steps_per_epoch=train_steps,
    epochs=num_epochs,
    validation_data=test_dataset,
    validation_steps=valid_steps,
    callbacks=callbacks
)
# Out:
# 945 945
# 756 756 189 189
# Train: 756 - 756
# Valid: 189 - 189
# Epoch 1/30
# 75/75 [==============================] - ETA: 0s - loss: 0.6955 - dice_coef: 0.5932 - iou: 0.4339 - accuracy: 0.7710 - recall: 0.6579 - precision: 0.8535
# Epoch 1: val_loss improved from inf to 2.49642, saving model to /content/drive/MyDrive/PFA/files_vgg19/model.h5
# 75/75 [==============================] - 246s 3s/step - loss: 0.6955 - dice_coef: 0.5932 - iou: 0.4339 - accuracy: 0.7710 - recall: 0.6579 - precision: 0.8535 - val_loss: 2.4964 - val_dice_coef: 0.3873 - val_iou: 0.2404 - val_accuracy: 0.4081 - val_recall: 0.3489 - val_precision: 0.4112 - lr: 1.0000e-04
# Epoch 2/30
# 75/75 [==============================] - ETA: 0s - loss: 0.3458 - dice_coef: 0.7862 - iou: 0.6481 - accuracy: 0.8923 - recall: 0.8714 - precision: 0.9088
# Epoch 2: val_loss improved from 2.49642 to 0.99374, saving model to /content/drive/MyDrive/PFA/files_vgg19/model.h5
# 75/75 [==============================] - 116s 1s/step - loss: 0.3458 - dice_coef: 0.7862 - iou: 0.6481 - accuracy: 0.8923 - recall: 0.8714 - precision: 0.9088 - val_loss: 0.9937 - val_dice_coef: 0.5510 - val_iou: 0.3803 - val_accuracy: 0.7299 - val_recall: 0.4943 - val_precision: 0.7150 - lr: 1.0000e-04
# Epoch 3/30
# 75/75 [==============================] - ETA: 0s - loss: 0.2756 - dice_coef: 0.8262 - iou: 0.7040 - accuracy: 0.9081 - recall: 0.8957 - precision: 0.9181
# Epoch 3: val_loss improved from 0.99374 to 0.32359, saving model to /content/drive/MyDrive/PFA/files_vgg19/model.h5
# 75/75 [==============================] - 107s 1s/step - loss: 0.2756 - dice_coef: 0.8262 - iou: 0.7040 - accuracy: 0.9081 - recall: 0.8957 - precision: 0.9181 - val_loss: 0.3236 - val_dice_coef: 0.7813 - val_iou: 0.6412 - val_accuracy: 0.9042 - val_recall: 0.8860 - val_precision: 0.9186 - lr: 1.0000e-04
# Epoch 4/30
# 75/75 [==============================] - ETA: 0s - loss: 0.2329 - dice_coef: 0.8526 - iou: 0.7431 - accuracy: 0.9195 - recall: 0.9116 - precision: 0.9261
# Epoch 4: val_loss improved from 0.32359 to 0.24566, saving model to /content/drive/MyDrive/PFA/files_vgg19/model.h5
# 75/75 [==============================] - 107s 1s/step - loss: 0.2329 - dice_coef: 0.8526 - iou: 0.7431 - accuracy: 0.9195 - recall: 0.9116 - precision: 0.9261 - val_loss: 0.2457 - val_dice_coef: 0.8433 - val_iou: 0.7291 - val_accuracy: 0.9155 - val_recall: 0.9077 - val_precision: 0.9221 - lr: 1.0000e-04
# Epoch 5/30
# 75/75 [==============================] - ETA: 0s - loss: 0.2134 - dice_coef: 0.8646 - iou: 0.7616 - accuracy: 0.9241 - recall: 0.9180 - precision: 0.9293
# Epoch 5: val_loss did not improve from 0.24566
# 75/75 [==============================] - 105s 1s/step - loss: 0.2134 - dice_coef: 0.8646 - iou: 0.7616 - accuracy: 0.9241 - recall: 0.9180 - precision: 0.9293 - val_loss: 0.2744 - val_dice_coef: 0.8476 - val_iou: 0.7356 - val_accuracy: 0.8958 - val_recall: 0.8902 - val_precision: 0.9005 - lr: 1.0000e-04
# Epoch 6/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1973 - dice_coef: 0.8757 - iou: 0.7790 - accuracy: 0.9283 - recall: 0.9237 - precision: 0.9323
# Epoch 6: val_loss did not improve from 0.24566
# 75/75 [==============================] - 102s 1s/step - loss: 0.1973 - dice_coef: 0.8757 - iou: 0.7790 - accuracy: 0.9283 - recall: 0.9237 - precision: 0.9323 - val_loss: 0.2576 - val_dice_coef: 0.8557 - val_iou: 0.7479 - val_accuracy: 0.8972 - val_recall: 0.8931 - val_precision: 0.9007 - lr: 1.0000e-04
# Epoch 7/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1826 - dice_coef: 0.8853 - iou: 0.7943 - accuracy: 0.9332 - recall: 0.9295 - precision: 0.9365
# Epoch 7: val_loss improved from 0.24566 to 0.20799, saving model to /content/drive/MyDrive/PFA/files_vgg19/model.h5
# 75/75 [==============================] - 106s 1s/step - loss: 0.1826 - dice_coef: 0.8853 - iou: 0.7943 - accuracy: 0.9332 - recall: 0.9295 - precision: 0.9365 - val_loss: 0.2080 - val_dice_coef: 0.8761 - val_iou: 0.7797 - val_accuracy: 0.9199 - val_recall: 0.9163 - val_precision: 0.9233 - lr: 1.0000e-04
# Epoch 8/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1690 - dice_coef: 0.8931 - iou: 0.8069 - accuracy: 0.9369 - recall: 0.9338 - precision: 0.9397
# Epoch 8: val_loss did not improve from 0.20799
# 75/75 [==============================] - 105s 1s/step - loss: 0.1690 - dice_coef: 0.8931 - iou: 0.8069 - accuracy: 0.9369 - recall: 0.9338 - precision: 0.9397 - val_loss: 0.3940 - val_dice_coef: 0.8430 - val_iou: 0.7289 - val_accuracy: 0.8682 - val_recall: 0.8658 - val_precision: 0.8702 - lr: 1.0000e-04
# Epoch 9/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1551 - dice_coef: 0.9018 - iou: 0.8212 - accuracy: 0.9419 - recall: 0.9394 - precision: 0.9443
# Epoch 9: val_loss did not improve from 0.20799
# 75/75 [==============================] - 105s 1s/step - loss: 0.1551 - dice_coef: 0.9018 - iou: 0.8212 - accuracy: 0.9419 - recall: 0.9394 - precision: 0.9443 - val_loss: 0.4943 - val_dice_coef: 0.8181 - val_iou: 0.6927 - val_accuracy: 0.8416 - val_recall: 0.8393 - val_precision: 0.8433 - lr: 1.0000e-04
# Epoch 10/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1468 - dice_coef: 0.9071 - iou: 0.8301 - accuracy: 0.9443 - recall: 0.9422 - precision: 0.9463
# Epoch 10: val_loss did not improve from 0.20799
# 75/75 [==============================] - 102s 1s/step - loss: 0.1468 - dice_coef: 0.9071 - iou: 0.8301 - accuracy: 0.9443 - recall: 0.9422 - precision: 0.9463 - val_loss: 0.3234 - val_dice_coef: 0.8631 - val_iou: 0.7593 - val_accuracy: 0.8852 - val_recall: 0.8836 - val_precision: 0.8866 - lr: 1.0000e-04
# Epoch 11/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1336 - dice_coef: 0.9158 - iou: 0.8447 - accuracy: 0.9496 - recall: 0.9477 - precision: 0.9513
# Epoch 11: val_loss did not improve from 0.20799
# 75/75 [==============================] - 102s 1s/step - loss: 0.1336 - dice_coef: 0.9158 - iou: 0.8447 - accuracy: 0.9496 - recall: 0.9477 - precision: 0.9513 - val_loss: 0.2245 - val_dice_coef: 0.8868 - val_iou: 0.7969 - val_accuracy: 0.9152 - val_recall: 0.9131 - val_precision: 0.9173 - lr: 1.0000e-04
# Epoch 12/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1239 - dice_coef: 0.9216 - iou: 0.8546 - accuracy: 0.9532 - recall: 0.9518 - precision: 0.9547
# Epoch 12: val_loss did not improve from 0.20799
# 75/75 [==============================] - 105s 1s/step - loss: 0.1239 - dice_coef: 0.9216 - iou: 0.8546 - accuracy: 0.9532 - recall: 0.9518 - precision: 0.9547 - val_loss: 0.2169 - val_dice_coef: 0.8951 - val_iou: 0.8102 - val_accuracy: 0.9207 - val_recall: 0.9190 - val_precision: 0.9223 - lr: 1.0000e-04
# Epoch 13/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1108 - dice_coef: 0.9299 - iou: 0.8690 - accuracy: 0.9577 - recall: 0.9564 - precision: 0.9590
# Epoch 13: val_loss did not improve from 0.20799
# 75/75 [==============================] - 105s 1s/step - loss: 0.1108 - dice_coef: 0.9299 - iou: 0.8690 - accuracy: 0.9577 - recall: 0.9564 - precision: 0.9590 - val_loss: 0.2314 - val_dice_coef: 0.8958 - val_iou: 0.8113 - val_accuracy: 0.9179 - val_recall: 0.9164 - val_precision: 0.9193 - lr: 1.0000e-04
# Epoch 14/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1082 - dice_coef: 0.9321 - iou: 0.8729 - accuracy: 0.9585 - recall: 0.9574 - precision: 0.9597
# Epoch 14: val_loss improved from 0.20799 to 0.20062, saving model to /content/drive/MyDrive/PFA/files_vgg19/model.h5
# 75/75 [==============================] - 106s 1s/step - loss: 0.1082 - dice_coef: 0.9321 - iou: 0.8729 - accuracy: 0.9585 - recall: 0.9574 - precision: 0.9597 - val_loss: 0.2006 - val_dice_coef: 0.9034 - val_iou: 0.8239 - val_accuracy: 0.9254 - val_recall: 0.9241 - val_precision: 0.9265 - lr: 1.0000e-04
# Epoch 15/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0971 - dice_coef: 0.9381 - iou: 0.8835 - accuracy: 0.9629 - recall: 0.9618 - precision: 0.9640
# Epoch 15: val_loss did not improve from 0.20062
# 75/75 [==============================] - 102s 1s/step - loss: 0.0971 - dice_coef: 0.9381 - iou: 0.8835 - accuracy: 0.9629 - recall: 0.9618 - precision: 0.9640 - val_loss: 0.3901 - val_dice_coef: 0.8727 - val_iou: 0.7743 - val_accuracy: 0.8884 - val_recall: 0.8872 - val_precision: 0.8895 - lr: 1.0000e-04
# Epoch 16/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1027 - dice_coef: 0.9360 - iou: 0.8797 - accuracy: 0.9602 - recall: 0.9592 - precision: 0.9611
# Epoch 16: val_loss did not improve from 0.20062
# 75/75 [==============================] - 102s 1s/step - loss: 0.1027 - dice_coef: 0.9360 - iou: 0.8797 - accuracy: 0.9602 - recall: 0.9592 - precision: 0.9611 - val_loss: 0.2369 - val_dice_coef: 0.9011 - val_iou: 0.8202 - val_accuracy: 0.9200 - val_recall: 0.9190 - val_precision: 0.9210 - lr: 1.0000e-04
# Epoch 17/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0897 - dice_coef: 0.9437 - iou: 0.8935 - accuracy: 0.9655 - recall: 0.9647 - precision: 0.9663
# Epoch 17: val_loss did not improve from 0.20062
# 75/75 [==============================] - 104s 1s/step - loss: 0.0897 - dice_coef: 0.9437 - iou: 0.8935 - accuracy: 0.9655 - recall: 0.9647 - precision: 0.9663 - val_loss: 0.2280 - val_dice_coef: 0.9045 - val_iou: 0.8259 - val_accuracy: 0.9223 - val_recall: 0.9215 - val_precision: 0.9232 - lr: 1.0000e-04
# Epoch 18/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0838 - dice_coef: 0.9472 - iou: 0.8996 - accuracy: 0.9677 - recall: 0.9669 - precision: 0.9684
# Epoch 18: val_loss did not improve from 0.20062
# 75/75 [==============================] - 105s 1s/step - loss: 0.0838 - dice_coef: 0.9472 - iou: 0.8996 - accuracy: 0.9677 - recall: 0.9669 - precision: 0.9684 - val_loss: 0.2139 - val_dice_coef: 0.9123 - val_iou: 0.8388 - val_accuracy: 0.9286 - val_recall: 0.9278 - val_precision: 0.9293 - lr: 1.0000e-04
# Epoch 19/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0826 - dice_coef: 0.9485 - iou: 0.9021 - accuracy: 0.9682 - recall: 0.9675 - precision: 0.9688
# Epoch 19: val_loss did not improve from 0.20062
# 75/75 [==============================] - 102s 1s/step - loss: 0.0826 - dice_coef: 0.9485 - iou: 0.9021 - accuracy: 0.9682 - recall: 0.9675 - precision: 0.9688 - val_loss: 0.2634 - val_dice_coef: 0.9044 - val_iou: 0.8256 - val_accuracy: 0.9187 - val_recall: 0.9177 - val_precision: 0.9197 - lr: 1.0000e-04
# Epoch 20/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0778 - dice_coef: 0.9512 - iou: 0.9070 - accuracy: 0.9695 - recall: 0.9689 - precision: 0.9701
# Epoch 20: val_loss did not improve from 0.20062
# 75/75 [==============================] - 102s 1s/step - loss: 0.0778 - dice_coef: 0.9512 - iou: 0.9070 - accuracy: 0.9695 - recall: 0.9689 - precision: 0.9701 - val_loss: 0.2071 - val_dice_coef: 0.9167 - val_iou: 0.8463 - val_accuracy: 0.9312 - val_recall: 0.9305 - val_precision: 0.9319 - lr: 1.0000e-04
# Epoch 21/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0750 - dice_coef: 0.9529 - iou: 0.9101 - accuracy: 0.9707 - recall: 0.9701 - precision: 0.9713
# Epoch 21: val_loss did not improve from 0.20062
# 75/75 [==============================] - 102s 1s/step - loss: 0.0750 - dice_coef: 0.9529 - iou: 0.9101 - accuracy: 0.9707 - recall: 0.9701 - precision: 0.9713 - val_loss: 0.2517 - val_dice_coef: 0.9102 - val_iou: 0.8353 - val_accuracy: 0.9232 - val_recall: 0.9225 - val_precision: 0.9239 - lr: 1.0000e-04
# Epoch 22/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0768 - dice_coef: 0.9525 - iou: 0.9094 - accuracy: 0.9698 - recall: 0.9693 - precision: 0.9703
# Epoch 22: val_loss did not improve from 0.20062
# 75/75 [==============================] - 105s 1s/step - loss: 0.0768 - dice_coef: 0.9525 - iou: 0.9094 - accuracy: 0.9698 - recall: 0.9693 - precision: 0.9703 - val_loss: 0.2217 - val_dice_coef: 0.9155 - val_iou: 0.8442 - val_accuracy: 0.9280 - val_recall: 0.9273 - val_precision: 0.9287 - lr: 1.0000e-04
# Epoch 23/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0760 - dice_coef: 0.9529 - iou: 0.9101 - accuracy: 0.9700 - recall: 0.9695 - precision: 0.9705
# Epoch 23: val_loss did not improve from 0.20062
# 75/75 [==============================] - 103s 1s/step - loss: 0.0760 - dice_coef: 0.9529 - iou: 0.9101 - accuracy: 0.9700 - recall: 0.9695 - precision: 0.9705 - val_loss: 0.2191 - val_dice_coef: 0.9165 - val_iou: 0.8459 - val_accuracy: 0.9291 - val_recall: 0.9286 - val_precision: 0.9296 - lr: 1.0000e-04
# Epoch 24/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0685 - dice_coef: 0.9570 - iou: 0.9176 - accuracy: 0.9729 - recall: 0.9724 - precision: 0.9733
# Epoch 24: val_loss did not improve from 0.20062
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 75/75 [==============================] - 104s 1s/step - loss: 0.0685 - dice_coef: 0.9570 - iou: 0.9176 - accuracy: 0.9729 - recall: 0.9724 - precision: 0.9733 - val_loss: 0.2272 - val_dice_coef: 0.9174 - val_iou: 0.8474 - val_accuracy: 0.9290 - val_recall: 0.9284 - val_precision: 0.9295 - lr: 1.0000e-04
# Epoch 25/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0602 - dice_coef: 0.9607 - iou: 0.9245 - accuracy: 0.9768 - recall: 0.9764 - precision: 0.9773
# Epoch 25: val_loss did not improve from 0.20062
# 75/75 [==============================] - 104s 1s/step - loss: 0.0602 - dice_coef: 0.9607 - iou: 0.9245 - accuracy: 0.9768 - recall: 0.9764 - precision: 0.9773 - val_loss: 0.2245 - val_dice_coef: 0.9199 - val_iou: 0.8518 - val_accuracy: 0.9311 - val_recall: 0.9306 - val_precision: 0.9316 - lr: 1.0000e-05
# Epoch 26/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0560 - dice_coef: 0.9632 - iou: 0.9291 - accuracy: 0.9785 - recall: 0.9781 - precision: 0.9789
# Epoch 26: val_loss did not improve from 0.20062
# 75/75 [==============================] - 104s 1s/step - loss: 0.0560 - dice_coef: 0.9632 - iou: 0.9291 - accuracy: 0.9785 - recall: 0.9781 - precision: 0.9789 - val_loss: 0.2236 - val_dice_coef: 0.9216 - val_iou: 0.8546 - val_accuracy: 0.9323 - val_recall: 0.9318 - val_precision: 0.9327 - lr: 1.0000e-05
# Epoch 27/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0530 - dice_coef: 0.9651 - iou: 0.9326 - accuracy: 0.9799 - recall: 0.9795 - precision: 0.9803
# Epoch 27: val_loss did not improve from 0.20062
# 75/75 [==============================] - 103s 1s/step - loss: 0.0530 - dice_coef: 0.9651 - iou: 0.9326 - accuracy: 0.9799 - recall: 0.9795 - precision: 0.9803 - val_loss: 0.2310 - val_dice_coef: 0.9211 - val_iou: 0.8538 - val_accuracy: 0.9313 - val_recall: 0.9309 - val_precision: 0.9318 - lr: 1.0000e-05
# Epoch 28/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0524 - dice_coef: 0.9657 - iou: 0.9338 - accuracy: 0.9799 - recall: 0.9795 - precision: 0.9803
# Epoch 28: val_loss did not improve from 0.20062
# 75/75 [==============================] - 106s 1s/step - loss: 0.0524 - dice_coef: 0.9657 - iou: 0.9338 - accuracy: 0.9799 - recall: 0.9795 - precision: 0.9803 - val_loss: 0.2395 - val_dice_coef: 0.9214 - val_iou: 0.8543 - val_accuracy: 0.9314 - val_recall: 0.9310 - val_precision: 0.9318 - lr: 1.0000e-05
# Epoch 29/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0505 - dice_coef: 0.9670 - iou: 0.9361 - accuracy: 0.9808 - recall: 0.9804 - precision: 0.9812
# Epoch 29: val_loss did not improve from 0.20062
# 75/75 [==============================] - 103s 1s/step - loss: 0.0505 - dice_coef: 0.9670 - iou: 0.9361 - accuracy: 0.9808 - recall: 0.9804 - precision: 0.9812 - val_loss: 0.2421 - val_dice_coef: 0.9216 - val_iou: 0.8548 - val_accuracy: 0.9312 - val_recall: 0.9308 - val_precision: 0.9316 - lr: 1.0000e-05
# Epoch 30/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0496 - dice_coef: 0.9677 - iou: 0.9375 - accuracy: 0.9813 - recall: 0.9809 - precision: 0.9817
# Epoch 30: val_loss did not improve from 0.20062
# 75/75 [==============================] - 106s 1s/step - loss: 0.0496 - dice_coef: 0.9677 - iou: 0.9375 - accuracy: 0.9813 - recall: 0.9809 - precision: 0.9817 - val_loss: 0.2430 - val_dice_coef: 0.9226 - val_iou: 0.8564 - val_accuracy: 0.9319 - val_recall: 0.9315 - val_precision: 0.9324 - lr: 1.0000e-05

# %%
# Plot the chart for accuracy and loss on both training and validation
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation precision')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
def load_data(path):

    images = sorted(glob(f"{path}/ROI/*.bmp"))
    masks = sorted(glob(f"{path}/label/*.bmp"))
    
    print(len(images), len(masks))
   
    return (images, masks)

# %%
test_path = os.path.join(dataset_path, "test")
(test_x, test_y) = load_data(test_path)
# Out:
# 48 48

# %%
from tqdm import tqdm

# %%
num_classes = 4

# %%
res_path = os.path.join(dataset_path, "results_vgg19")
create_dir(res_path)
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
        name = x.split("/")[-1]

        ## Read image
        
        x = cv2.imread(x, cv2.IMREAD_COLOR)
        x = x / 255.0
        x = x.astype(np.float32)

        ## Read mask
        y = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
        y[y == 255] = 0
        y[y == 223] = 1 #ZP
        y[y == 127] = 2 #TE
        y[y == 191] = 3 #ICM
        y[ y > 3] = 0
        y = np.expand_dims(y, axis=-1) ## (256, 256, 1)
        y = y * (255/num_classes)
        y = y.astype(np.int32)
        y = np.concatenate([y, y, y], axis=2)

        ## Prediction
        p = model.predict(np.expand_dims(x, axis=0))[0]
        p = np.argmax(p, axis=-1)
        p = np.expand_dims(p, axis=-1)
        p = p * (255/num_classes)
        p = p.astype(np.int32)
        p = np.concatenate([p, p, p], axis=2)

        x = x * 255.0
        x = x.astype(np.int32)

        h, w, _ = x.shape
        line = np.ones((h, 10, 3)) * 255

        print(x.shape, line.shape, y.shape, line.shape, p.shape)

        final_image = np.concatenate([x, line, y, line, p], axis=1)
        status = cv2.imwrite(f"{res_path}/{name}", final_image)
        print(status)
# Out:
#   2%|▏         | 1/48 [00:02<02:19,  2.97s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#   4%|▍         | 2/48 [00:03<01:10,  1.53s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#   6%|▋         | 3/48 [00:04<00:51,  1.14s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#   8%|▊         | 4/48 [00:04<00:40,  1.10it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  10%|█         | 5/48 [00:05<00:35,  1.21it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  12%|█▎        | 6/48 [00:06<00:31,  1.32it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  15%|█▍        | 7/48 [00:06<00:29,  1.39it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  17%|█▋        | 8/48 [00:07<00:29,  1.38it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  19%|█▉        | 9/48 [00:07<00:26,  1.50it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  21%|██        | 10/48 [00:08<00:25,  1.47it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  23%|██▎       | 11/48 [00:09<00:25,  1.43it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  25%|██▌       | 12/48 [00:10<00:24,  1.49it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  27%|██▋       | 13/48 [00:10<00:22,  1.58it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  29%|██▉       | 14/48 [00:11<00:21,  1.58it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  31%|███▏      | 15/48 [00:11<00:20,  1.58it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  33%|███▎      | 16/48 [00:12<00:19,  1.63it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  35%|███▌      | 17/48 [00:12<00:18,  1.65it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  38%|███▊      | 18/48 [00:14<00:23,  1.27it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  40%|███▉      | 19/48 [00:15<00:24,  1.19it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  42%|████▏     | 20/48 [00:15<00:21,  1.29it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  44%|████▍     | 21/48 [00:16<00:21,  1.27it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  46%|████▌     | 22/48 [00:17<00:19,  1.36it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  48%|████▊     | 23/48 [00:17<00:17,  1.47it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  50%|█████     | 24/48 [00:18<00:16,  1.50it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  52%|█████▏    | 25/48 [00:18<00:14,  1.56it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  54%|█████▍    | 26/48 [00:19<00:14,  1.52it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  56%|█████▋    | 27/48 [00:20<00:14,  1.47it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  58%|█████▊    | 28/48 [00:20<00:13,  1.52it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  60%|██████    | 29/48 [00:21<00:12,  1.56it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  62%|██████▎   | 30/48 [00:22<00:11,  1.55it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  65%|██████▍   | 31/48 [00:23<00:12,  1.39it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  67%|██████▋   | 32/48 [00:23<00:10,  1.51it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  69%|██████▉   | 33/48 [00:24<00:09,  1.58it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  71%|███████   | 34/48 [00:24<00:08,  1.59it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  73%|███████▎  | 35/48 [00:25<00:08,  1.58it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  75%|███████▌  | 36/48 [00:26<00:07,  1.64it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  77%|███████▋  | 37/48 [00:26<00:06,  1.62it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  79%|███████▉  | 38/48 [00:27<00:06,  1.61it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  81%|████████▏ | 39/48 [00:27<00:05,  1.67it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  83%|████████▎ | 40/48 [00:28<00:04,  1.64it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  85%|████████▌ | 41/48 [00:29<00:04,  1.64it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  88%|████████▊ | 42/48 [00:30<00:04,  1.41it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  90%|████████▉ | 43/48 [00:30<00:03,  1.46it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  92%|█████████▏| 44/48 [00:31<00:02,  1.58it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  94%|█████████▍| 45/48 [00:31<00:01,  1.57it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  96%|█████████▌| 46/48 [00:32<00:01,  1.51it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  98%|█████████▊| 47/48 [00:33<00:00,  1.51it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
# 100%|██████████| 48/48 [00:33<00:00,  1.42it/s]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
