# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50

# %%
def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

# %%
def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

# %%
def build_resnet50_unet(input_shape):
    """ Input """
    inputs = Input(input_shape)

    """ Pre-trained ResNet50 Model """
    resnet50 = ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)

    """ Encoder """
    s1 = resnet50.layers[0].output           ## (512 x 512)
    s2 = resnet50.get_layer("conv1_relu").output        ## (256 x 256)
    s3 = resnet50.get_layer("conv2_block3_out").output  ## (128 x 128)
    s4 = resnet50.get_layer("conv3_block4_out").output  ## (64 x 64)

    """ Bridge """
    b1 = resnet50.get_layer("conv4_block6_out").output  ## (32 x 32)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)                     ## (64 x 64)
    d2 = decoder_block(d1, s3, 256)                     ## (128 x 128)
    d3 = decoder_block(d2, s2, 128)                     ## (256 x 256)
    d4 = decoder_block(d3, s1, 64)                      ## (512 x 512)

    """ Output """
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="ResNet50_U-Net")
    return model

# %%
input_shape = (256, 256, 3)
model = build_resnet50_unet(input_shape)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step
# Model: "ResNet50_U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 262, 262, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 128, 128, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 128, 128, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 128, 128, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 130, 130, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 64, 64, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 64, 64, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 64, 64, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 64, 64, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 64, 64, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 64, 64, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 64, 64, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 64, 64, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 64, 64, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 64, 64, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 64, 64, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 64, 64, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 64, 64, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 64, 64, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 64, 64, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 64, 64, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 64, 64, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 64, 64, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 64, 64, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 64, 64, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 64, 64, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 32, 32, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 32, 32, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 32, 32, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 32, 32, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 32, 32, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 32, 32, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 16, 16, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 16, 16, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 16, 16, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 16, 16, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 16, 16, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 16, 16, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 16, 16, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 16, 16, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 512)  2097664    ['conv4_block6_out[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'conv3_block4_out[0][0]']
#
#  conv2d (Conv2D)                (None, 32, 32, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 512)  2048       ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 512)  0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 512)  2359808     ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 256)  524544     ['activation_1[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2_block3_out[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 256)  1179904     ['concatenate_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 12  131200     ['activation_3[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 19  0           ['conv2d_transpose_2[0][0]',
#                                 2)                                'conv1_relu[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 12  221312      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 12  512        ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  activation_4 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_4[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 12  147584      ['activation_4[0][0]']
#                                 8)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  activation_5 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_5[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 64  32832      ['activation_5[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 67  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'input_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 256, 256, 64  38656       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 256, 256, 64  256        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 256, 256, 64  36928       ['activation_6[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 256, 256, 64  256        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 256, 256, 1)  65          ['activation_7[0][0]']
#
# ==================================================================================================
# Total params: 20,676,545
# Trainable params: 20,642,113
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive_path = '/content/drive/MyDrive/PFA'

# %%
import os

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision, Accuracy, IoU
from sklearn.model_selection import train_test_split

# %%
H = 256
W = 256

def create_dir(path):
    """Create a directory"""
    if not os.path.exists(path):
        os.mkdir(path)

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def load_data(path):
    images = sorted(glob(f"{path}/ROI/*.bmp"))
    masks = sorted(glob(f"{path}/GT_ZP/*.bmp"))
    
    print(len(masks), len(images))

    train_x, valid_x = train_test_split(images, test_size=0.2, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=0.2, random_state=42)
    print(len(train_x), len(train_y), len(valid_x), len(valid_y))
   
    return (train_x, train_y), (valid_x, valid_y)

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = x / 255.0
    x = x.astype(np.float32)
    
    return x

def read_mask(path):
    path = path.decode('utf-8')
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    '''
    x[x == 255] = 0
    x[x == 223] = 1 #ZP
    x[x == 127] = 2 #TE
    x[x == 191] = 3 #ICM
    x[ x > 3] = 0
    
    x = x.astype(np.int32)
    '''
    x[x!=0] =255
    x = x/255.0
    x = x > 0.5
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)
    
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32,  tf.float32]) #was tf.int32
    #y = tf.one_hot(y, 2, dtype=tf.int32)
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1]) #was 4

    return x, y

def tf_dataset(x, y, batch=8):
    
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.shuffle(buffer_size=5000)
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.repeat()
    dataset = dataset.prefetch(2)
    '''
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    '''
    return dataset

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

"""Directory for storing files"""
create_dir("/content/drive/MyDrive/PFA/files_resnet50")

"""Hyperparameters"""
batch_size = 10
learning_rate = 1e-4
num_epochs = 70
model_path = os.path.join("/content/drive/MyDrive/PFA/files_resnet50", "model_zp.h5")
csv_path = os.path.join("/content/drive/MyDrive/PFA/files_resnet50", "data_zp.csv")

"""Dataset"""
dataset_path = os.path.join("/content/drive/MyDrive/PFA/new_data")
train_path = os.path.join(dataset_path, "train")

(train_x, train_y), (valid_x, valid_y) = load_data(train_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
test_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

"""Model"""

model = build_resnet50_unet((H, W, 3))
metrics = [dice_coef, iou, 'accuracy', Recall(), Precision()]
model.compile(loss=dice_loss, optimizer=Adam(learning_rate), metrics=metrics)

train_steps = len(train_x)//batch_size
valid_steps = len(valid_x)//batch_size

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-7, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=False)
]

history = model.fit(
    train_dataset,
    steps_per_epoch=train_steps,
    epochs=num_epochs,
    validation_data=test_dataset,
    validation_steps=valid_steps,
    callbacks=callbacks
)
# Out:
# 945 945
# 756 756 189 189
# Train: 756 - 756
# Valid: 189 - 189
# Epoch 1/70
# 75/75 [==============================] - ETA: 0s - loss: 0.3838 - dice_coef: 0.6162 - iou: 0.4567 - accuracy: 0.8713 - recall_5: 0.9416 - precision_5: 0.5559
# Epoch 1: val_loss improved from inf to 0.74540, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 900s 12s/step - loss: 0.3838 - dice_coef: 0.6162 - iou: 0.4567 - accuracy: 0.8713 - recall_5: 0.9416 - precision_5: 0.5559 - val_loss: 0.7454 - val_dice_coef: 0.2546 - val_iou: 0.1461 - val_accuracy: 0.5257 - val_recall_5: 0.7807 - val_precision_5: 0.2192 - lr: 1.0000e-04
# Epoch 2/70
# 75/75 [==============================] - ETA: 0s - loss: 0.2482 - dice_coef: 0.7517 - iou: 0.6035 - accuracy: 0.9522 - recall_5: 0.9280 - precision_5: 0.8038
# Epoch 2: val_loss did not improve from 0.74540
# 75/75 [==============================] - 44s 590ms/step - loss: 0.2482 - dice_coef: 0.7517 - iou: 0.6035 - accuracy: 0.9522 - recall_5: 0.9280 - precision_5: 0.8038 - val_loss: 0.8130 - val_dice_coef: 0.1870 - val_iou: 0.1032 - val_accuracy: 0.8421 - val_recall_5: 0.0068 - val_precision_5: 0.8472 - lr: 1.0000e-04
# Epoch 3/70
# 75/75 [==============================] - ETA: 0s - loss: 0.2154 - dice_coef: 0.7838 - iou: 0.6463 - accuracy: 0.9611 - recall_5: 0.9348 - precision_5: 0.8383
# Epoch 3: val_loss did not improve from 0.74540
# 75/75 [==============================] - 37s 497ms/step - loss: 0.2154 - dice_coef: 0.7838 - iou: 0.6463 - accuracy: 0.9611 - recall_5: 0.9348 - precision_5: 0.8383 - val_loss: 0.8780 - val_dice_coef: 0.1220 - val_iou: 0.0650 - val_accuracy: 0.8424 - val_recall_5: 4.4356e-04 - val_precision_5: 0.9494 - lr: 1.0000e-04
# Epoch 4/70
# 75/75 [==============================] - ETA: 0s - loss: 0.1852 - dice_coef: 0.8146 - iou: 0.6879 - accuracy: 0.9682 - recall_5: 0.9411 - precision_5: 0.8688
# Epoch 4: val_loss did not improve from 0.74540
# 75/75 [==============================] - 40s 540ms/step - loss: 0.1852 - dice_coef: 0.8146 - iou: 0.6879 - accuracy: 0.9682 - recall_5: 0.9411 - precision_5: 0.8688 - val_loss: 0.8465 - val_dice_coef: 0.1535 - val_iou: 0.0832 - val_accuracy: 0.8475 - val_recall_5: 0.0522 - val_precision_5: 0.8947 - lr: 1.0000e-04
# Epoch 5/70
# 75/75 [==============================] - ETA: 0s - loss: 0.1598 - dice_coef: 0.8399 - iou: 0.7248 - accuracy: 0.9730 - recall_5: 0.9457 - precision_5: 0.8922
# Epoch 5: val_loss improved from 0.74540 to 0.68966, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 44s 589ms/step - loss: 0.1598 - dice_coef: 0.8399 - iou: 0.7248 - accuracy: 0.9730 - recall_5: 0.9457 - precision_5: 0.8922 - val_loss: 0.6897 - val_dice_coef: 0.3103 - val_iou: 0.1842 - val_accuracy: 0.8669 - val_recall_5: 0.1902 - val_precision_5: 0.9275 - lr: 1.0000e-04
# Epoch 6/70
# 75/75 [==============================] - ETA: 0s - loss: 0.1421 - dice_coef: 0.8579 - iou: 0.7518 - accuracy: 0.9765 - recall_5: 0.9482 - precision_5: 0.9081
# Epoch 6: val_loss improved from 0.68966 to 0.43275, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 45s 594ms/step - loss: 0.1421 - dice_coef: 0.8579 - iou: 0.7518 - accuracy: 0.9765 - recall_5: 0.9482 - precision_5: 0.9081 - val_loss: 0.4327 - val_dice_coef: 0.5673 - val_iou: 0.3964 - val_accuracy: 0.9058 - val_recall_5: 0.4813 - val_precision_5: 0.8852 - lr: 1.0000e-04
# Epoch 7/70
# 75/75 [==============================] - ETA: 0s - loss: 0.1296 - dice_coef: 0.8704 - iou: 0.7712 - accuracy: 0.9784 - recall_5: 0.9508 - precision_5: 0.9151
# Epoch 7: val_loss improved from 0.43275 to 0.31636, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 44s 593ms/step - loss: 0.1296 - dice_coef: 0.8704 - iou: 0.7712 - accuracy: 0.9784 - recall_5: 0.9508 - precision_5: 0.9151 - val_loss: 0.3164 - val_dice_coef: 0.6836 - val_iou: 0.5201 - val_accuracy: 0.9325 - val_recall_5: 0.6174 - val_precision_5: 0.9393 - lr: 1.0000e-04
# Epoch 8/70
# 75/75 [==============================] - ETA: 0s - loss: 0.1174 - dice_coef: 0.8827 - iou: 0.7904 - accuracy: 0.9789 - recall_5: 0.9509 - precision_5: 0.9198
# Epoch 8: val_loss improved from 0.31636 to 0.24519, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 43s 571ms/step - loss: 0.1174 - dice_coef: 0.8827 - iou: 0.7904 - accuracy: 0.9789 - recall_5: 0.9509 - precision_5: 0.9198 - val_loss: 0.2452 - val_dice_coef: 0.7548 - val_iou: 0.6068 - val_accuracy: 0.9438 - val_recall_5: 0.7328 - val_precision_5: 0.8976 - lr: 1.0000e-04
# Epoch 9/70
# 75/75 [==============================] - ETA: 0s - loss: 0.1041 - dice_coef: 0.8959 - iou: 0.8118 - accuracy: 0.9815 - recall_5: 0.9529 - precision_5: 0.9326
# Epoch 9: val_loss improved from 0.24519 to 0.18644, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 45s 604ms/step - loss: 0.1041 - dice_coef: 0.8959 - iou: 0.8118 - accuracy: 0.9815 - recall_5: 0.9529 - precision_5: 0.9326 - val_loss: 0.1864 - val_dice_coef: 0.8136 - val_iou: 0.6865 - val_accuracy: 0.9547 - val_recall_5: 0.8497 - val_precision_5: 0.8649 - lr: 1.0000e-04
# Epoch 10/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0956 - dice_coef: 0.9043 - iou: 0.8257 - accuracy: 0.9830 - recall_5: 0.9549 - precision_5: 0.9387
# Epoch 10: val_loss improved from 0.18644 to 0.17097, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 46s 610ms/step - loss: 0.0956 - dice_coef: 0.9043 - iou: 0.8257 - accuracy: 0.9830 - recall_5: 0.9549 - precision_5: 0.9387 - val_loss: 0.1710 - val_dice_coef: 0.8290 - val_iou: 0.7085 - val_accuracy: 0.9559 - val_recall_5: 0.8627 - val_precision_5: 0.8608 - lr: 1.0000e-04
# Epoch 11/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0906 - dice_coef: 0.9094 - iou: 0.8343 - accuracy: 0.9827 - recall_5: 0.9560 - precision_5: 0.9368
# Epoch 11: val_loss improved from 0.17097 to 0.15826, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 43s 576ms/step - loss: 0.0906 - dice_coef: 0.9094 - iou: 0.8343 - accuracy: 0.9827 - recall_5: 0.9560 - precision_5: 0.9368 - val_loss: 0.1583 - val_dice_coef: 0.8417 - val_iou: 0.7274 - val_accuracy: 0.9579 - val_recall_5: 0.8879 - val_precision_5: 0.8534 - lr: 1.0000e-04
# Epoch 12/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0816 - dice_coef: 0.9184 - iou: 0.8494 - accuracy: 0.9849 - recall_5: 0.9576 - precision_5: 0.9472
# Epoch 12: val_loss did not improve from 0.15826
# 75/75 [==============================] - 42s 562ms/step - loss: 0.0816 - dice_coef: 0.9184 - iou: 0.8494 - accuracy: 0.9849 - recall_5: 0.9576 - precision_5: 0.9472 - val_loss: 0.1784 - val_dice_coef: 0.8216 - val_iou: 0.6983 - val_accuracy: 0.9445 - val_recall_5: 0.9521 - val_precision_5: 0.7587 - lr: 1.0000e-04
# Epoch 13/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0752 - dice_coef: 0.9247 - iou: 0.8603 - accuracy: 0.9854 - recall_5: 0.9612 - precision_5: 0.9480
# Epoch 13: val_loss improved from 0.15826 to 0.15533, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 44s 593ms/step - loss: 0.0752 - dice_coef: 0.9247 - iou: 0.8603 - accuracy: 0.9854 - recall_5: 0.9612 - precision_5: 0.9480 - val_loss: 0.1553 - val_dice_coef: 0.8447 - val_iou: 0.7320 - val_accuracy: 0.9532 - val_recall_5: 0.9468 - val_precision_5: 0.7958 - lr: 1.0000e-04
# Epoch 14/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0702 - dice_coef: 0.9298 - iou: 0.8690 - accuracy: 0.9861 - recall_5: 0.9615 - precision_5: 0.9518
# Epoch 14: val_loss improved from 0.15533 to 0.15018, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 44s 581ms/step - loss: 0.0702 - dice_coef: 0.9298 - iou: 0.8690 - accuracy: 0.9861 - recall_5: 0.9615 - precision_5: 0.9518 - val_loss: 0.1502 - val_dice_coef: 0.8498 - val_iou: 0.7395 - val_accuracy: 0.9557 - val_recall_5: 0.9399 - val_precision_5: 0.8093 - lr: 1.0000e-04
# Epoch 15/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0662 - dice_coef: 0.9337 - iou: 0.8759 - accuracy: 0.9867 - recall_5: 0.9653 - precision_5: 0.9517
# Epoch 15: val_loss improved from 0.15018 to 0.14323, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 44s 583ms/step - loss: 0.0662 - dice_coef: 0.9337 - iou: 0.8759 - accuracy: 0.9867 - recall_5: 0.9653 - precision_5: 0.9517 - val_loss: 0.1432 - val_dice_coef: 0.8568 - val_iou: 0.7499 - val_accuracy: 0.9580 - val_recall_5: 0.9195 - val_precision_5: 0.8365 - lr: 1.0000e-04
# Epoch 16/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0675 - dice_coef: 0.9326 - iou: 0.8740 - accuracy: 0.9853 - recall_5: 0.9584 - precision_5: 0.9503
# Epoch 16: val_loss did not improve from 0.14323
# 75/75 [==============================] - 40s 539ms/step - loss: 0.0675 - dice_coef: 0.9326 - iou: 0.8740 - accuracy: 0.9853 - recall_5: 0.9584 - precision_5: 0.9503 - val_loss: 0.1499 - val_dice_coef: 0.8501 - val_iou: 0.7399 - val_accuracy: 0.9523 - val_recall_5: 0.9541 - val_precision_5: 0.7911 - lr: 1.0000e-04
# Epoch 17/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0593 - dice_coef: 0.9407 - iou: 0.8882 - accuracy: 0.9874 - recall_5: 0.9639 - precision_5: 0.9571
# Epoch 17: val_loss did not improve from 0.14323
# 75/75 [==============================] - 41s 543ms/step - loss: 0.0593 - dice_coef: 0.9407 - iou: 0.8882 - accuracy: 0.9874 - recall_5: 0.9639 - precision_5: 0.9571 - val_loss: 0.1448 - val_dice_coef: 0.8552 - val_iou: 0.7476 - val_accuracy: 0.9548 - val_recall_5: 0.9389 - val_precision_5: 0.8097 - lr: 1.0000e-04
# Epoch 18/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0566 - dice_coef: 0.9434 - iou: 0.8929 - accuracy: 0.9877 - recall_5: 0.9643 - precision_5: 0.9585
# Epoch 18: val_loss improved from 0.14323 to 0.14112, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 47s 631ms/step - loss: 0.0566 - dice_coef: 0.9434 - iou: 0.8929 - accuracy: 0.9877 - recall_5: 0.9643 - precision_5: 0.9585 - val_loss: 0.1411 - val_dice_coef: 0.8589 - val_iou: 0.7537 - val_accuracy: 0.9563 - val_recall_5: 0.9406 - val_precision_5: 0.8157 - lr: 1.0000e-04
# Epoch 19/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0538 - dice_coef: 0.9462 - iou: 0.8980 - accuracy: 0.9881 - recall_5: 0.9649 - precision_5: 0.9604
# Epoch 19: val_loss improved from 0.14112 to 0.13732, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 46s 614ms/step - loss: 0.0538 - dice_coef: 0.9462 - iou: 0.8980 - accuracy: 0.9881 - recall_5: 0.9649 - precision_5: 0.9604 - val_loss: 0.1373 - val_dice_coef: 0.8627 - val_iou: 0.7594 - val_accuracy: 0.9579 - val_recall_5: 0.9457 - val_precision_5: 0.8169 - lr: 1.0000e-04
# Epoch 20/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0499 - dice_coef: 0.9500 - iou: 0.9049 - accuracy: 0.9890 - recall_5: 0.9683 - precision_5: 0.9624
# Epoch 20: val_loss improved from 0.13732 to 0.12210, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 46s 616ms/step - loss: 0.0499 - dice_coef: 0.9500 - iou: 0.9049 - accuracy: 0.9890 - recall_5: 0.9683 - precision_5: 0.9624 - val_loss: 0.1221 - val_dice_coef: 0.8779 - val_iou: 0.7827 - val_accuracy: 0.9651 - val_recall_5: 0.8985 - val_precision_5: 0.8827 - lr: 1.0000e-04
# Epoch 21/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0458 - dice_coef: 0.9542 - iou: 0.9125 - accuracy: 0.9899 - recall_5: 0.9704 - precision_5: 0.9661
# Epoch 21: val_loss improved from 0.12210 to 0.11982, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 43s 579ms/step - loss: 0.0458 - dice_coef: 0.9542 - iou: 0.9125 - accuracy: 0.9899 - recall_5: 0.9704 - precision_5: 0.9661 - val_loss: 0.1198 - val_dice_coef: 0.8802 - val_iou: 0.7865 - val_accuracy: 0.9655 - val_recall_5: 0.8994 - val_precision_5: 0.8862 - lr: 1.0000e-04
# Epoch 22/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0446 - dice_coef: 0.9554 - iou: 0.9146 - accuracy: 0.9901 - recall_5: 0.9705 - precision_5: 0.9670
# Epoch 22: val_loss did not improve from 0.11982
# 75/75 [==============================] - 43s 568ms/step - loss: 0.0446 - dice_coef: 0.9554 - iou: 0.9146 - accuracy: 0.9901 - recall_5: 0.9705 - precision_5: 0.9670 - val_loss: 0.1239 - val_dice_coef: 0.8761 - val_iou: 0.7798 - val_accuracy: 0.9642 - val_recall_5: 0.8884 - val_precision_5: 0.8860 - lr: 1.0000e-04
# Epoch 23/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0427 - dice_coef: 0.9574 - iou: 0.9183 - accuracy: 0.9898 - recall_5: 0.9702 - precision_5: 0.9674
# Epoch 23: val_loss improved from 0.11982 to 0.11940, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 46s 612ms/step - loss: 0.0427 - dice_coef: 0.9574 - iou: 0.9183 - accuracy: 0.9898 - recall_5: 0.9702 - precision_5: 0.9674 - val_loss: 0.1194 - val_dice_coef: 0.8806 - val_iou: 0.7868 - val_accuracy: 0.9651 - val_recall_5: 0.8813 - val_precision_5: 0.9001 - lr: 1.0000e-04
# Epoch 24/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0415 - dice_coef: 0.9586 - iou: 0.9205 - accuracy: 0.9904 - recall_5: 0.9718 - precision_5: 0.9676
# Epoch 24: val_loss did not improve from 0.11940
# 75/75 [==============================] - 40s 537ms/step - loss: 0.0415 - dice_coef: 0.9586 - iou: 0.9205 - accuracy: 0.9904 - recall_5: 0.9718 - precision_5: 0.9676 - val_loss: 0.1216 - val_dice_coef: 0.8784 - val_iou: 0.7838 - val_accuracy: 0.9632 - val_recall_5: 0.9216 - val_precision_5: 0.8570 - lr: 1.0000e-04
# Epoch 25/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0404 - dice_coef: 0.9596 - iou: 0.9224 - accuracy: 0.9904 - recall_5: 0.9725 - precision_5: 0.9674
# Epoch 25: val_loss improved from 0.11940 to 0.11789, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 46s 616ms/step - loss: 0.0404 - dice_coef: 0.9596 - iou: 0.9224 - accuracy: 0.9904 - recall_5: 0.9725 - precision_5: 0.9674 - val_loss: 0.1179 - val_dice_coef: 0.8821 - val_iou: 0.7894 - val_accuracy: 0.9650 - val_recall_5: 0.8941 - val_precision_5: 0.8871 - lr: 1.0000e-04
# Epoch 26/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0387 - dice_coef: 0.9613 - iou: 0.9255 - accuracy: 0.9907 - recall_5: 0.9717 - precision_5: 0.9697
# Epoch 26: val_loss improved from 0.11789 to 0.11303, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 44s 585ms/step - loss: 0.0387 - dice_coef: 0.9613 - iou: 0.9255 - accuracy: 0.9907 - recall_5: 0.9717 - precision_5: 0.9697 - val_loss: 0.1130 - val_dice_coef: 0.8870 - val_iou: 0.7971 - val_accuracy: 0.9661 - val_recall_5: 0.8999 - val_precision_5: 0.8896 - lr: 1.0000e-04
# Epoch 27/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0374 - dice_coef: 0.9626 - iou: 0.9279 - accuracy: 0.9910 - recall_5: 0.9741 - precision_5: 0.9691
# Epoch 27: val_loss did not improve from 0.11303
# 75/75 [==============================] - 43s 567ms/step - loss: 0.0374 - dice_coef: 0.9626 - iou: 0.9279 - accuracy: 0.9910 - recall_5: 0.9741 - precision_5: 0.9691 - val_loss: 0.1142 - val_dice_coef: 0.8858 - val_iou: 0.7953 - val_accuracy: 0.9664 - val_recall_5: 0.8759 - val_precision_5: 0.9114 - lr: 1.0000e-04
# Epoch 28/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0376 - dice_coef: 0.9624 - iou: 0.9275 - accuracy: 0.9905 - recall_5: 0.9717 - precision_5: 0.9692
# Epoch 28: val_loss did not improve from 0.11303
# 75/75 [==============================] - 43s 567ms/step - loss: 0.0376 - dice_coef: 0.9624 - iou: 0.9275 - accuracy: 0.9905 - recall_5: 0.9717 - precision_5: 0.9692 - val_loss: 0.1186 - val_dice_coef: 0.8814 - val_iou: 0.7885 - val_accuracy: 0.9658 - val_recall_5: 0.8641 - val_precision_5: 0.9147 - lr: 1.0000e-04
# Epoch 29/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0355 - dice_coef: 0.9645 - iou: 0.9315 - accuracy: 0.9912 - recall_5: 0.9736 - precision_5: 0.9708
# Epoch 29: val_loss did not improve from 0.11303
# 75/75 [==============================] - 43s 567ms/step - loss: 0.0355 - dice_coef: 0.9645 - iou: 0.9315 - accuracy: 0.9912 - recall_5: 0.9736 - precision_5: 0.9708 - val_loss: 0.1149 - val_dice_coef: 0.8851 - val_iou: 0.7941 - val_accuracy: 0.9651 - val_recall_5: 0.8863 - val_precision_5: 0.8971 - lr: 1.0000e-04
# Epoch 30/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0355 - dice_coef: 0.9646 - iou: 0.9316 - accuracy: 0.9909 - recall_5: 0.9734 - precision_5: 0.9699
# Epoch 30: val_loss did not improve from 0.11303
# 75/75 [==============================] - 43s 568ms/step - loss: 0.0355 - dice_coef: 0.9646 - iou: 0.9316 - accuracy: 0.9909 - recall_5: 0.9734 - precision_5: 0.9699 - val_loss: 0.1181 - val_dice_coef: 0.8819 - val_iou: 0.7894 - val_accuracy: 0.9650 - val_recall_5: 0.8766 - val_precision_5: 0.9000 - lr: 1.0000e-04
# Epoch 31/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0340 - dice_coef: 0.9660 - iou: 0.9342 - accuracy: 0.9913 - recall_5: 0.9741 - precision_5: 0.9713
# Epoch 31: val_loss did not improve from 0.11303
# 75/75 [==============================] - 43s 570ms/step - loss: 0.0340 - dice_coef: 0.9660 - iou: 0.9342 - accuracy: 0.9913 - recall_5: 0.9741 - precision_5: 0.9713 - val_loss: 0.1149 - val_dice_coef: 0.8851 - val_iou: 0.7943 - val_accuracy: 0.9649 - val_recall_5: 0.8987 - val_precision_5: 0.8845 - lr: 1.0000e-04
# Epoch 32/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0340 - dice_coef: 0.9660 - iou: 0.9343 - accuracy: 0.9912 - recall_5: 0.9736 - precision_5: 0.9710
# Epoch 32: val_loss did not improve from 0.11303
# 75/75 [==============================] - 43s 569ms/step - loss: 0.0340 - dice_coef: 0.9660 - iou: 0.9343 - accuracy: 0.9912 - recall_5: 0.9736 - precision_5: 0.9710 - val_loss: 0.1151 - val_dice_coef: 0.8849 - val_iou: 0.7939 - val_accuracy: 0.9652 - val_recall_5: 0.8769 - val_precision_5: 0.9034 - lr: 1.0000e-04
# Epoch 33/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0337 - dice_coef: 0.9663 - iou: 0.9348 - accuracy: 0.9912 - recall_5: 0.9737 - precision_5: 0.9709
# Epoch 33: val_loss did not improve from 0.11303
# 75/75 [==============================] - 43s 569ms/step - loss: 0.0337 - dice_coef: 0.9663 - iou: 0.9348 - accuracy: 0.9912 - recall_5: 0.9737 - precision_5: 0.9709 - val_loss: 0.1135 - val_dice_coef: 0.8865 - val_iou: 0.7965 - val_accuracy: 0.9663 - val_recall_5: 0.8778 - val_precision_5: 0.9071 - lr: 1.0000e-04
# Epoch 34/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0326 - dice_coef: 0.9674 - iou: 0.9370 - accuracy: 0.9912 - recall_5: 0.9742 - precision_5: 0.9715
# Epoch 34: val_loss improved from 0.11303 to 0.10890, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 46s 611ms/step - loss: 0.0326 - dice_coef: 0.9674 - iou: 0.9370 - accuracy: 0.9912 - recall_5: 0.9742 - precision_5: 0.9715 - val_loss: 0.1089 - val_dice_coef: 0.8911 - val_iou: 0.8040 - val_accuracy: 0.9664 - val_recall_5: 0.9040 - val_precision_5: 0.8895 - lr: 1.0000e-04
# Epoch 35/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0315 - dice_coef: 0.9685 - iou: 0.9389 - accuracy: 0.9918 - recall_5: 0.9752 - precision_5: 0.9727
# Epoch 35: val_loss did not improve from 0.10890
# 75/75 [==============================] - 43s 568ms/step - loss: 0.0315 - dice_coef: 0.9685 - iou: 0.9389 - accuracy: 0.9918 - recall_5: 0.9752 - precision_5: 0.9727 - val_loss: 0.1129 - val_dice_coef: 0.8871 - val_iou: 0.7973 - val_accuracy: 0.9661 - val_recall_5: 0.8782 - val_precision_5: 0.9047 - lr: 1.0000e-04
# Epoch 36/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0311 - dice_coef: 0.9690 - iou: 0.9398 - accuracy: 0.9915 - recall_5: 0.9743 - precision_5: 0.9730
# Epoch 36: val_loss did not improve from 0.10890
# 75/75 [==============================] - 41s 544ms/step - loss: 0.0311 - dice_coef: 0.9690 - iou: 0.9398 - accuracy: 0.9915 - recall_5: 0.9743 - precision_5: 0.9730 - val_loss: 0.1129 - val_dice_coef: 0.8871 - val_iou: 0.7975 - val_accuracy: 0.9655 - val_recall_5: 0.8869 - val_precision_5: 0.8954 - lr: 1.0000e-04
# Epoch 37/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0298 - dice_coef: 0.9701 - iou: 0.9421 - accuracy: 0.9922 - recall_5: 0.9762 - precision_5: 0.9739
# Epoch 37: val_loss did not improve from 0.10890
# 75/75 [==============================] - 41s 546ms/step - loss: 0.0298 - dice_coef: 0.9701 - iou: 0.9421 - accuracy: 0.9922 - recall_5: 0.9762 - precision_5: 0.9739 - val_loss: 0.1119 - val_dice_coef: 0.8881 - val_iou: 0.7990 - val_accuracy: 0.9653 - val_recall_5: 0.8984 - val_precision_5: 0.8860 - lr: 1.0000e-04
# Epoch 38/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0295 - dice_coef: 0.9705 - iou: 0.9428 - accuracy: 0.9920 - recall_5: 0.9761 - precision_5: 0.9740
# Epoch 38: val_loss did not improve from 0.10890
# 75/75 [==============================] - 41s 546ms/step - loss: 0.0295 - dice_coef: 0.9705 - iou: 0.9428 - accuracy: 0.9920 - recall_5: 0.9761 - precision_5: 0.9740 - val_loss: 0.1144 - val_dice_coef: 0.8856 - val_iou: 0.7951 - val_accuracy: 0.9648 - val_recall_5: 0.8981 - val_precision_5: 0.8821 - lr: 1.0000e-04
# Epoch 39/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0278 - dice_coef: 0.9722 - iou: 0.9459 - accuracy: 0.9924 - recall_5: 0.9775 - precision_5: 0.9751
# Epoch 39: val_loss did not improve from 0.10890
# 75/75 [==============================] - 41s 547ms/step - loss: 0.0278 - dice_coef: 0.9722 - iou: 0.9459 - accuracy: 0.9924 - recall_5: 0.9775 - precision_5: 0.9751 - val_loss: 0.1103 - val_dice_coef: 0.8897 - val_iou: 0.8017 - val_accuracy: 0.9656 - val_recall_5: 0.9074 - val_precision_5: 0.8798 - lr: 1.0000e-04
# Epoch 40/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0277 - dice_coef: 0.9723 - iou: 0.9460 - accuracy: 0.9925 - recall_5: 0.9777 - precision_5: 0.9749
# Epoch 40: val_loss did not improve from 0.10890
# 75/75 [==============================] - 43s 577ms/step - loss: 0.0277 - dice_coef: 0.9723 - iou: 0.9460 - accuracy: 0.9925 - recall_5: 0.9777 - precision_5: 0.9749 - val_loss: 0.1105 - val_dice_coef: 0.8895 - val_iou: 0.8013 - val_accuracy: 0.9660 - val_recall_5: 0.8988 - val_precision_5: 0.8887 - lr: 1.0000e-04
# Epoch 41/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0283 - dice_coef: 0.9717 - iou: 0.9450 - accuracy: 0.9921 - recall_5: 0.9763 - precision_5: 0.9745
# Epoch 41: val_loss did not improve from 0.10890
# 75/75 [==============================] - 42s 561ms/step - loss: 0.0283 - dice_coef: 0.9717 - iou: 0.9450 - accuracy: 0.9921 - recall_5: 0.9763 - precision_5: 0.9745 - val_loss: 0.1126 - val_dice_coef: 0.8874 - val_iou: 0.7981 - val_accuracy: 0.9659 - val_recall_5: 0.8791 - val_precision_5: 0.9031 - lr: 1.0000e-04
# Epoch 42/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0281 - dice_coef: 0.9718 - iou: 0.9452 - accuracy: 0.9923 - recall_5: 0.9766 - precision_5: 0.9745
# Epoch 42: val_loss did not improve from 0.10890
# 75/75 [==============================] - 40s 539ms/step - loss: 0.0281 - dice_coef: 0.9718 - iou: 0.9452 - accuracy: 0.9923 - recall_5: 0.9766 - precision_5: 0.9745 - val_loss: 0.1162 - val_dice_coef: 0.8838 - val_iou: 0.7921 - val_accuracy: 0.9650 - val_recall_5: 0.8635 - val_precision_5: 0.9123 - lr: 1.0000e-04
# Epoch 43/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0269 - dice_coef: 0.9731 - iou: 0.9476 - accuracy: 0.9924 - recall_5: 0.9778 - precision_5: 0.9751
# Epoch 43: val_loss did not improve from 0.10890
# 75/75 [==============================] - 41s 544ms/step - loss: 0.0269 - dice_coef: 0.9731 - iou: 0.9476 - accuracy: 0.9924 - recall_5: 0.9778 - precision_5: 0.9751 - val_loss: 0.1130 - val_dice_coef: 0.8870 - val_iou: 0.7974 - val_accuracy: 0.9654 - val_recall_5: 0.8728 - val_precision_5: 0.9078 - lr: 1.0000e-04
# Epoch 44/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0262 - dice_coef: 0.9738 - iou: 0.9489 - accuracy: 0.9927 - recall_5: 0.9780 - precision_5: 0.9762
# Epoch 44: val_loss did not improve from 0.10890
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 75/75 [==============================] - 40s 540ms/step - loss: 0.0262 - dice_coef: 0.9738 - iou: 0.9489 - accuracy: 0.9927 - recall_5: 0.9780 - precision_5: 0.9762 - val_loss: 0.1129 - val_dice_coef: 0.8871 - val_iou: 0.7976 - val_accuracy: 0.9651 - val_recall_5: 0.8835 - val_precision_5: 0.8964 - lr: 1.0000e-04
# Epoch 45/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0228 - dice_coef: 0.9771 - iou: 0.9552 - accuracy: 0.9936 - recall_5: 0.9814 - precision_5: 0.9791
# Epoch 45: val_loss did not improve from 0.10890
# 75/75 [==============================] - 40s 539ms/step - loss: 0.0228 - dice_coef: 0.9771 - iou: 0.9552 - accuracy: 0.9936 - recall_5: 0.9814 - precision_5: 0.9791 - val_loss: 0.1114 - val_dice_coef: 0.8886 - val_iou: 0.7998 - val_accuracy: 0.9657 - val_recall_5: 0.8760 - val_precision_5: 0.9070 - lr: 1.0000e-05
# Epoch 46/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0206 - dice_coef: 0.9794 - iou: 0.9597 - accuracy: 0.9946 - recall_5: 0.9838 - precision_5: 0.9816
# Epoch 46: val_loss did not improve from 0.10890
# 75/75 [==============================] - 43s 568ms/step - loss: 0.0206 - dice_coef: 0.9794 - iou: 0.9597 - accuracy: 0.9946 - recall_5: 0.9838 - precision_5: 0.9816 - val_loss: 0.1107 - val_dice_coef: 0.8893 - val_iou: 0.8010 - val_accuracy: 0.9660 - val_recall_5: 0.8792 - val_precision_5: 0.9049 - lr: 1.0000e-05
# Epoch 47/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0194 - dice_coef: 0.9806 - iou: 0.9620 - accuracy: 0.9948 - recall_5: 0.9846 - precision_5: 0.9831
# Epoch 47: val_loss did not improve from 0.10890
# 75/75 [==============================] - 40s 536ms/step - loss: 0.0194 - dice_coef: 0.9806 - iou: 0.9620 - accuracy: 0.9948 - recall_5: 0.9846 - precision_5: 0.9831 - val_loss: 0.1096 - val_dice_coef: 0.8904 - val_iou: 0.8028 - val_accuracy: 0.9662 - val_recall_5: 0.8810 - val_precision_5: 0.9048 - lr: 1.0000e-05
# Epoch 48/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0185 - dice_coef: 0.9815 - iou: 0.9638 - accuracy: 0.9951 - recall_5: 0.9852 - precision_5: 0.9842
# Epoch 48: val_loss improved from 0.10890 to 0.10873, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 46s 610ms/step - loss: 0.0185 - dice_coef: 0.9815 - iou: 0.9638 - accuracy: 0.9951 - recall_5: 0.9852 - precision_5: 0.9842 - val_loss: 0.1087 - val_dice_coef: 0.8913 - val_iou: 0.8042 - val_accuracy: 0.9667 - val_recall_5: 0.8794 - val_precision_5: 0.9092 - lr: 1.0000e-05
# Epoch 49/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0178 - dice_coef: 0.9822 - iou: 0.9650 - accuracy: 0.9954 - recall_5: 0.9862 - precision_5: 0.9846
# Epoch 49: val_loss did not improve from 0.10873
# 75/75 [==============================] - 40s 539ms/step - loss: 0.0178 - dice_coef: 0.9822 - iou: 0.9650 - accuracy: 0.9954 - recall_5: 0.9862 - precision_5: 0.9846 - val_loss: 0.1105 - val_dice_coef: 0.8895 - val_iou: 0.8015 - val_accuracy: 0.9663 - val_recall_5: 0.8741 - val_precision_5: 0.9109 - lr: 1.0000e-05
# Epoch 50/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0176 - dice_coef: 0.9824 - iou: 0.9655 - accuracy: 0.9955 - recall_5: 0.9860 - precision_5: 0.9853
# Epoch 50: val_loss did not improve from 0.10873
# 75/75 [==============================] - 43s 570ms/step - loss: 0.0176 - dice_coef: 0.9824 - iou: 0.9655 - accuracy: 0.9955 - recall_5: 0.9860 - precision_5: 0.9853 - val_loss: 0.1099 - val_dice_coef: 0.8901 - val_iou: 0.8024 - val_accuracy: 0.9663 - val_recall_5: 0.8820 - val_precision_5: 0.9039 - lr: 1.0000e-05
# Epoch 51/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0167 - dice_coef: 0.9833 - iou: 0.9672 - accuracy: 0.9957 - recall_5: 0.9872 - precision_5: 0.9859
# Epoch 51: val_loss improved from 0.10873 to 0.10865, saving model to /content/drive/MyDrive/PFA/files_resnet50/model_zp.h5
# 75/75 [==============================] - 44s 584ms/step - loss: 0.0167 - dice_coef: 0.9833 - iou: 0.9672 - accuracy: 0.9957 - recall_5: 0.9872 - precision_5: 0.9859 - val_loss: 0.1086 - val_dice_coef: 0.8914 - val_iou: 0.8042 - val_accuracy: 0.9667 - val_recall_5: 0.8802 - val_precision_5: 0.9074 - lr: 1.0000e-05
# Epoch 52/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0164 - dice_coef: 0.9836 - iou: 0.9678 - accuracy: 0.9957 - recall_5: 0.9873 - precision_5: 0.9863
# Epoch 52: val_loss did not improve from 0.10865
# 75/75 [==============================] - 43s 569ms/step - loss: 0.0164 - dice_coef: 0.9836 - iou: 0.9678 - accuracy: 0.9957 - recall_5: 0.9873 - precision_5: 0.9863 - val_loss: 0.1112 - val_dice_coef: 0.8888 - val_iou: 0.8002 - val_accuracy: 0.9663 - val_recall_5: 0.8771 - val_precision_5: 0.9073 - lr: 1.0000e-05
# Epoch 53/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0167 - dice_coef: 0.9833 - iou: 0.9671 - accuracy: 0.9958 - recall_5: 0.9874 - precision_5: 0.9859
# Epoch 53: val_loss did not improve from 0.10865
# 75/75 [==============================] - 42s 567ms/step - loss: 0.0167 - dice_coef: 0.9833 - iou: 0.9671 - accuracy: 0.9958 - recall_5: 0.9874 - precision_5: 0.9859 - val_loss: 0.1095 - val_dice_coef: 0.8905 - val_iou: 0.8030 - val_accuracy: 0.9661 - val_recall_5: 0.8783 - val_precision_5: 0.9088 - lr: 1.0000e-05
# Epoch 54/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0156 - dice_coef: 0.9844 - iou: 0.9692 - accuracy: 0.9959 - recall_5: 0.9881 - precision_5: 0.9866
# Epoch 54: val_loss did not improve from 0.10865
# 75/75 [==============================] - 43s 569ms/step - loss: 0.0156 - dice_coef: 0.9844 - iou: 0.9692 - accuracy: 0.9959 - recall_5: 0.9881 - precision_5: 0.9866 - val_loss: 0.1095 - val_dice_coef: 0.8905 - val_iou: 0.8029 - val_accuracy: 0.9663 - val_recall_5: 0.8798 - val_precision_5: 0.9070 - lr: 1.0000e-05
# Epoch 55/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0157 - dice_coef: 0.9843 - iou: 0.9691 - accuracy: 0.9960 - recall_5: 0.9882 - precision_5: 0.9867
# Epoch 55: val_loss did not improve from 0.10865
# 75/75 [==============================] - 42s 566ms/step - loss: 0.0157 - dice_coef: 0.9843 - iou: 0.9691 - accuracy: 0.9960 - recall_5: 0.9882 - precision_5: 0.9867 - val_loss: 0.1112 - val_dice_coef: 0.8888 - val_iou: 0.8001 - val_accuracy: 0.9664 - val_recall_5: 0.8743 - val_precision_5: 0.9098 - lr: 1.0000e-05
# Epoch 56/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0152 - dice_coef: 0.9849 - iou: 0.9702 - accuracy: 0.9961 - recall_5: 0.9882 - precision_5: 0.9876
# Epoch 56: val_loss did not improve from 0.10865
# 75/75 [==============================] - 40s 539ms/step - loss: 0.0152 - dice_coef: 0.9849 - iou: 0.9702 - accuracy: 0.9961 - recall_5: 0.9882 - precision_5: 0.9876 - val_loss: 0.1087 - val_dice_coef: 0.8913 - val_iou: 0.8041 - val_accuracy: 0.9663 - val_recall_5: 0.8818 - val_precision_5: 0.9048 - lr: 1.0000e-05
# Epoch 57/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0153 - dice_coef: 0.9847 - iou: 0.9699 - accuracy: 0.9961 - recall_5: 0.9885 - precision_5: 0.9870
# Epoch 57: val_loss did not improve from 0.10865
# 75/75 [==============================] - 40s 540ms/step - loss: 0.0153 - dice_coef: 0.9847 - iou: 0.9699 - accuracy: 0.9961 - recall_5: 0.9885 - precision_5: 0.9870 - val_loss: 0.1103 - val_dice_coef: 0.8897 - val_iou: 0.8018 - val_accuracy: 0.9661 - val_recall_5: 0.8746 - val_precision_5: 0.9101 - lr: 1.0000e-05
# Epoch 58/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0150 - dice_coef: 0.9850 - iou: 0.9704 - accuracy: 0.9962 - recall_5: 0.9885 - precision_5: 0.9875
# Epoch 58: val_loss did not improve from 0.10865
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 75/75 [==============================] - 43s 574ms/step - loss: 0.0150 - dice_coef: 0.9850 - iou: 0.9704 - accuracy: 0.9962 - recall_5: 0.9885 - precision_5: 0.9875 - val_loss: 0.1114 - val_dice_coef: 0.8886 - val_iou: 0.7999 - val_accuracy: 0.9662 - val_recall_5: 0.8744 - val_precision_5: 0.9093 - lr: 1.0000e-05
# Epoch 59/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0145 - dice_coef: 0.9855 - iou: 0.9714 - accuracy: 0.9963 - recall_5: 0.9883 - precision_5: 0.9886
# Epoch 59: val_loss did not improve from 0.10865
# 75/75 [==============================] - 43s 574ms/step - loss: 0.0145 - dice_coef: 0.9855 - iou: 0.9714 - accuracy: 0.9963 - recall_5: 0.9883 - precision_5: 0.9886 - val_loss: 0.1113 - val_dice_coef: 0.8887 - val_iou: 0.8002 - val_accuracy: 0.9663 - val_recall_5: 0.8780 - val_precision_5: 0.9056 - lr: 1.0000e-06
# Epoch 60/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0149 - dice_coef: 0.9851 - iou: 0.9707 - accuracy: 0.9963 - recall_5: 0.9890 - precision_5: 0.9875
# Epoch 60: val_loss did not improve from 0.10865
# 75/75 [==============================] - 43s 574ms/step - loss: 0.0149 - dice_coef: 0.9851 - iou: 0.9707 - accuracy: 0.9963 - recall_5: 0.9890 - precision_5: 0.9875 - val_loss: 0.1098 - val_dice_coef: 0.8902 - val_iou: 0.8025 - val_accuracy: 0.9663 - val_recall_5: 0.8790 - val_precision_5: 0.9069 - lr: 1.0000e-06
# Epoch 61/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9717 - accuracy: 0.9963 - recall_5: 0.9889 - precision_5: 0.9882
# Epoch 61: val_loss did not improve from 0.10865
# 75/75 [==============================] - 43s 573ms/step - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9717 - accuracy: 0.9963 - recall_5: 0.9889 - precision_5: 0.9882 - val_loss: 0.1110 - val_dice_coef: 0.8890 - val_iou: 0.8004 - val_accuracy: 0.9662 - val_recall_5: 0.8793 - val_precision_5: 0.9046 - lr: 1.0000e-06
# Epoch 62/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0145 - dice_coef: 0.9855 - iou: 0.9715 - accuracy: 0.9964 - recall_5: 0.9892 - precision_5: 0.9880
# Epoch 62: val_loss did not improve from 0.10865
# 75/75 [==============================] - 43s 574ms/step - loss: 0.0145 - dice_coef: 0.9855 - iou: 0.9715 - accuracy: 0.9964 - recall_5: 0.9892 - precision_5: 0.9880 - val_loss: 0.1114 - val_dice_coef: 0.8886 - val_iou: 0.7998 - val_accuracy: 0.9659 - val_recall_5: 0.8768 - val_precision_5: 0.9070 - lr: 1.0000e-06
# Epoch 63/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9715 - accuracy: 0.9964 - recall_5: 0.9892 - precision_5: 0.9880
# Epoch 63: val_loss did not improve from 0.10865
# 75/75 [==============================] - 41s 545ms/step - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9715 - accuracy: 0.9964 - recall_5: 0.9892 - precision_5: 0.9880 - val_loss: 0.1100 - val_dice_coef: 0.8900 - val_iou: 0.8021 - val_accuracy: 0.9662 - val_recall_5: 0.8782 - val_precision_5: 0.9071 - lr: 1.0000e-06
# Epoch 64/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0146 - dice_coef: 0.9854 - iou: 0.9713 - accuracy: 0.9964 - recall_5: 0.9891 - precision_5: 0.9879
# Epoch 64: val_loss did not improve from 0.10865
# 75/75 [==============================] - 42s 565ms/step - loss: 0.0146 - dice_coef: 0.9854 - iou: 0.9713 - accuracy: 0.9964 - recall_5: 0.9891 - precision_5: 0.9879 - val_loss: 0.1112 - val_dice_coef: 0.8888 - val_iou: 0.8006 - val_accuracy: 0.9659 - val_recall_5: 0.8774 - val_precision_5: 0.9079 - lr: 1.0000e-06
# Epoch 65/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9717 - accuracy: 0.9963 - recall_5: 0.9890 - precision_5: 0.9883
# Epoch 65: val_loss did not improve from 0.10865
# 75/75 [==============================] - 40s 539ms/step - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9717 - accuracy: 0.9963 - recall_5: 0.9890 - precision_5: 0.9883 - val_loss: 0.1113 - val_dice_coef: 0.8887 - val_iou: 0.8001 - val_accuracy: 0.9657 - val_recall_5: 0.8778 - val_precision_5: 0.9048 - lr: 1.0000e-06
# Epoch 66/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0145 - dice_coef: 0.9855 - iou: 0.9714 - accuracy: 0.9964 - recall_5: 0.9891 - precision_5: 0.9880
# Epoch 66: val_loss did not improve from 0.10865
# 75/75 [==============================] - 43s 574ms/step - loss: 0.0145 - dice_coef: 0.9855 - iou: 0.9714 - accuracy: 0.9964 - recall_5: 0.9891 - precision_5: 0.9880 - val_loss: 0.1095 - val_dice_coef: 0.8905 - val_iou: 0.8027 - val_accuracy: 0.9662 - val_recall_5: 0.8785 - val_precision_5: 0.9078 - lr: 1.0000e-06
# Epoch 67/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9717 - accuracy: 0.9964 - recall_5: 0.9893 - precision_5: 0.9881
# Epoch 67: val_loss did not improve from 0.10865
# 75/75 [==============================] - 40s 538ms/step - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9717 - accuracy: 0.9964 - recall_5: 0.9893 - precision_5: 0.9881 - val_loss: 0.1092 - val_dice_coef: 0.8908 - val_iou: 0.8034 - val_accuracy: 0.9662 - val_recall_5: 0.8796 - val_precision_5: 0.9073 - lr: 1.0000e-06
# Epoch 68/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0140 - dice_coef: 0.9860 - iou: 0.9723 - accuracy: 0.9964 - recall_5: 0.9894 - precision_5: 0.9883
# Epoch 68: val_loss did not improve from 0.10865
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1e-07.
# 75/75 [==============================] - 43s 571ms/step - loss: 0.0140 - dice_coef: 0.9860 - iou: 0.9723 - accuracy: 0.9964 - recall_5: 0.9894 - precision_5: 0.9883 - val_loss: 0.1107 - val_dice_coef: 0.8893 - val_iou: 0.8010 - val_accuracy: 0.9659 - val_recall_5: 0.8749 - val_precision_5: 0.9100 - lr: 1.0000e-06
# Epoch 69/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9716 - accuracy: 0.9964 - recall_5: 0.9887 - precision_5: 0.9886
# Epoch 69: val_loss did not improve from 0.10865
# 75/75 [==============================] - 42s 566ms/step - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9716 - accuracy: 0.9964 - recall_5: 0.9887 - precision_5: 0.9886 - val_loss: 0.1105 - val_dice_coef: 0.8895 - val_iou: 0.8012 - val_accuracy: 0.9658 - val_recall_5: 0.8758 - val_precision_5: 0.9081 - lr: 1.0000e-07
# Epoch 70/70
# 75/75 [==============================] - ETA: 0s - loss: 0.0144 - dice_coef: 0.9855 - iou: 0.9715 - accuracy: 0.9964 - recall_5: 0.9893 - precision_5: 0.9881
# Epoch 70: val_loss did not improve from 0.10865
# 75/75 [==============================] - 43s 568ms/step - loss: 0.0144 - dice_coef: 0.9855 - iou: 0.9715 - accuracy: 0.9964 - recall_5: 0.9893 - precision_5: 0.9881 - val_loss: 0.1117 - val_dice_coef: 0.8883 - val_iou: 0.7996 - val_accuracy: 0.9660 - val_recall_5: 0.8770 - val_precision_5: 0.9072 - lr: 1.0000e-07

# %%
# Plot the chart for accuracy and loss on both training and validation
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
def load_data(path):

    images = sorted(glob(f"{path}/ROI/*.bmp"))
    masks = sorted(glob(f"{path}/GT_ZP/*.bmp"))
    
    print(len(images), len(masks))
   
    return (images, masks)
    
test_path = os.path.join(dataset_path, "test")
(test_x, test_y) = load_data(test_path)
# Out:
# 48 48

# %%
from tqdm import tqdm

# %%
'''
# Load the previously saved weights
model = tf.keras.models.load_model('/content/drive/MyDrive/PFA/files_resnet50/model.h5',custom_objects={'dice_coef': dice_coef,'iou':iou})
'''
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-6da7ba5b14bd> in <module>()
#       1
#       2 # Load the previously saved weights
# ----> 3 model = tf.keras.models.load_model('/content/drive/MyDrive/PFA/files_resnet50/model.h5',custom_objects={'dice_coef': dice_coef,'iou':iou})
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     213             return hdf5_format.load_model_from_hdf5(
#     214                 tf.io.gfile.GFile(filepath_str, mode='rb'), custom_objects,
# --> 215                 compile)
#     216         elif h5py is not None and isinstance(filepath, h5py.File):
#     217           return hdf5_format.load_model_from_hdf5(filepath, custom_objects,
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     222         optimizer_weight_values = load_optimizer_weights_from_hdf5_group(f)
#     223         try:
# --> 224           model.optimizer.set_weights(optimizer_weight_values)
#     225         except ValueError:
#     226           logging.warning('Error in loading the saved optimizer '
#
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py in set_weights(self, weights)
#     152     if len(weights) == 3 * num_vars + 1:
#     153       weights = weights[:len(params)]
# --> 154     super(Adam, self).set_weights(weights)
#     155
#     156   def _resource_apply_dense(self, grad, var, apply_state=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py in set_weights(self, weights)
#    1156                          f"provided weight shape {str(w.shape)}.")
#    1157       weight_value_tuples.append((p, w))
# -> 1158     backend.batch_set_value(weight_value_tuples)
#    1159
#    1160   def add_weight(self,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1080       # Fallback dispatch system (dispatch v1):
#    1081       try:
# -> 1082         return dispatch_target(*args, **kwargs)
#    1083       except (TypeError, ValueError):
#    1084         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/keras/backend.py in batch_set_value(tuples)
#    4017   if tf.compat.v1.executing_eagerly_outside_functions():
#    4018     for x, value in tuples:
# -> 4019       x.assign(np.asarray(value, dtype=dtype_numpy(x)))
#    4020   else:
#    4021     with get_graph().as_default():
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py in assign(self, value, use_locking, name, read_value)
#     932     # initialize the variable.
#     933     with _handle_graph(self.handle):
# --> 934       value_tensor = ops.convert_to_tensor(value, dtype=self.dtype)
#     935       if not self._shape.is_compatible_with(value_tensor.shape):
#     936         if self.name is None:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#     184
#     185     return wrapped
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1693
#    1694     if ret is None:
# -> 1695       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1696
#    1697     if ret is NotImplemented:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      46 def _default_conversion_function(value, dtype, name, as_ref):
#      47   del as_ref  # Unused.
# ---> 48   return constant_op.constant(value, dtype, name=name)
#      49
#      50
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     266   """
#     267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 268                         allow_broadcast=True)
#     269
#     270
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     277       with trace.Trace("tf.constant"):
#     278         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 279     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     280
#     281   g = ops.get_default_graph()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     302 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     303   """Creates a constant on the current device."""
# --> 304   t = convert_to_eager_tensor(value, ctx, dtype)
#     305   if shape is None:
#     306     return t
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101   ctx.ensure_initialized()
# --> 102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#     104
#
# KeyboardInterrupt:

# %%
num_classes = 1
create_dir("/content/drive/MyDrive/PFA/single_resnet50_70_ZP/")
res_path = "/content/drive/MyDrive/PFA/single_resnet50_70_ZP/"
create_dir(res_path)
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
        name = x.split("/")[-1]

        ## Read image
        x = cv2.imread(x, cv2.IMREAD_COLOR)
        x = x / 255.0
        x = x.astype(np.float32)
        
        ## Read mask
        y = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
        y[y == 255] = 0
        y[y == 223] = 1 #ZP
        y[y == 127] = 2 #TE
        y[y == 191] = 3 #ICM
        y[ y > 3] = 0
        y = np.expand_dims(y, axis=-1) ## (256, 256, 1)
        y = y * (255/num_classes)
        y = y.astype(np.int32)
        y = np.concatenate([y, y, y], axis=2)

        ## Prediction
        
        p = model.predict(np.expand_dims(x, axis=0))[0]
        
        p = p > 0.5
        p = p.astype(np.int32)
        p = p *255
        '''
        mask = model.predict(x)[0]
        mask = mask > 0.5
        mask = mask.astype(np.int32)

        x = x * 255.0
        x = x.astype(np.int32)
        
        h, w, _ = x.shape
        line = np.ones((h, 10, 3)) * 255

        

        final_image = np.concatenate([x, line, y, line, p], axis=1)
        '''
        status = cv2.imwrite(f"{res_path}/{name}", p)
# Out:
# 100%|██████████| 48/48 [00:54<00:00,  1.14s/it]

# %%
from google.colab.patches import cv2_imshow
