# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPooling2D, Conv2DTranspose
from tensorflow.keras.layers import Concatenate, Input
from tensorflow.keras.models import Model

# %%
def conv_block(x, num_filters, kernel_size, padding="same", act=True):
    x = Conv2D(num_filters, kernel_size, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    if act:
        x = Activation("relu")(x)
    return x

# %%
def multires_block(x, num_filters, alpha=1.67):
    W = num_filters * alpha

    x0 = x
    x1 = conv_block(x0, int(W*0.167), 3)
    x2 = conv_block(x1, int(W*0.333), 3)
    x3 = conv_block(x2, int(W*0.5), 3)
    xc = Concatenate()([x1, x2, x3])
    xc = BatchNormalization()(xc)

    nf = int(W*0.167) + int(W*0.333) + int(W*0.5)
    sc = conv_block(x0, nf, 1, act=False)

    x = Activation("relu")(xc + sc)
    x = BatchNormalization()(x)
    return x

# %%
def res_path(x, num_filters, length):
    for i in range(length):
        x0 = x
        x1 = conv_block(x0, num_filters, 3, act=False)
        sc = conv_block(x0, num_filters, 1, act=False)
        x = Activation("relu")(x1 + sc)
        x = BatchNormalization()(x)
    return x

# %%
def encoder_block(x, num_filters, length):
    x = multires_block(x, num_filters)
    s = res_path(x, num_filters, length)
    p = MaxPooling2D((2, 2))(x)
    return s, p

def decoder_block(x, skip, num_filters):
    x = Conv2DTranspose(num_filters, 2, strides=2, padding="same")(x)
    x = Concatenate()([x, skip])
    x = multires_block(x, num_filters)
    return x

# %%
def build_multiresunet(shape,num_classes):
    """ Input """
    
    inputs = Input(shape)

    """ Encoder """
    p0 = inputs
    s1, p1 = encoder_block(p0, 32, 4)
    s2, p2 = encoder_block(p1, 64, 3)
    s3, p3 = encoder_block(p2, 128, 2)
    s4, p4 = encoder_block(p3, 256, 1)

    """ Bridge """
    b1 = multires_block(p4, 512)

    """ Decoder """
    d1 = decoder_block(b1, s4, 256)
    d2 = decoder_block(d1, s3, 128)
    d3 = decoder_block(d2, s2, 64)
    d4 = decoder_block(d3, s1, 32)

    """ Output """
    outputs = Conv2D(num_classes, 1, padding="same", activation="softmax")(d4)

    """ Model """
    model = Model(inputs, outputs, name="MultiResUNET")

    return model

# %%
shape = (256, 256, 3)
model = build_multiresunet(shape,4)
model.summary()
# Out:
# Model: "MultiResUNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 8)  216         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 256, 256, 8)  32         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 256, 256, 8)  0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 17  1224        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 17  68         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 17  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 26  3978        ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 26  104        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 256, 256, 26  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 256, 256, 51  0           ['activation[0][0]',
#                                 )                                 'activation_1[0][0]',
#                                                                   'activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 51  153         ['input_1[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 51  204        ['concatenate[0][0]']
#  rmalization)                   )
#
#  batch_normalization_4 (BatchNo  (None, 256, 256, 51  204        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  tf.__operators__.add (TFOpLamb  (None, 256, 256, 51  0          ['batch_normalization_3[0][0]',
#  da)                            )                                 'batch_normalization_4[0][0]']
#
#  activation_3 (Activation)      (None, 256, 256, 51  0           ['tf.__operators__.add[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 256, 256, 51  204        ['activation_3[0][0]']
#  rmalization)                   )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 51  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 17  7803        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 128, 128, 17  68         ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  activation_8 (Activation)      (None, 128, 128, 17  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 35  5355        ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 128, 128, 35  140        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  activation_9 (Activation)      (None, 128, 128, 35  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 53  16695       ['activation_9[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 128, 128, 53  212        ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  activation_10 (Activation)     (None, 128, 128, 53  0           ['batch_normalization_20[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 10  0           ['activation_8[0][0]',
#                                 5)                                'activation_9[0][0]',
#                                                                   'activation_10[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 10  5355        ['max_pooling2d[0][0]']
#                                 5)
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 10  420        ['concatenate_1[0][0]']
#  ormalization)                  5)
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 10  420        ['conv2d_15[0][0]']
#  ormalization)                  5)
#
#  tf.__operators__.add_5 (TFOpLa  (None, 128, 128, 10  0          ['batch_normalization_21[0][0]',
#  mbda)                          5)                                'batch_normalization_22[0][0]']
#
#  activation_11 (Activation)     (None, 128, 128, 10  0           ['tf.__operators__.add_5[0][0]']
#                                 5)
#
#  batch_normalization_23 (BatchN  (None, 128, 128, 10  420        ['activation_11[0][0]']
#  ormalization)                  5)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 105)  0          ['batch_normalization_23[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 35)   33075       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 64, 64, 35)  140         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 64, 35)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 71)   22365       ['activation_15[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 64, 64, 71)  284         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 64, 64, 71)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 106)  67734       ['activation_16[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 64, 64, 106)  424        ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 64, 64, 106)  0           ['batch_normalization_35[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 212)  0           ['activation_15[0][0]',
#                                                                   'activation_16[0][0]',
#                                                                   'activation_17[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 212)  22260       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 64, 64, 212)  848        ['concatenate_2[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 64, 64, 212)  848        ['conv2d_25[0][0]']
#  ormalization)
#
#  tf.__operators__.add_9 (TFOpLa  (None, 64, 64, 212)  0          ['batch_normalization_36[0][0]',
#  mbda)                                                            'batch_normalization_37[0][0]']
#
#  activation_18 (Activation)     (None, 64, 64, 212)  0           ['tf.__operators__.add_9[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 64, 64, 212)  848        ['activation_18[0][0]']
#  ormalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 212)  0          ['batch_normalization_38[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 71)   135468      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 32, 32, 71)  284         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 32, 32, 71)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 142)  90738       ['activation_21[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 32, 32, 142)  568        ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 32, 32, 142)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 32, 32, 213)  272214      ['activation_22[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 32, 32, 213)  852        ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 32, 32, 213)  0           ['batch_normalization_47[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 32, 32, 426)  0           ['activation_21[0][0]',
#                                                                   'activation_22[0][0]',
#                                                                   'activation_23[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 32, 32, 426)  90312       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 32, 32, 426)  1704       ['concatenate_3[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 32, 32, 426)  1704       ['conv2d_33[0][0]']
#  ormalization)
#
#  tf.__operators__.add_12 (TFOpL  (None, 32, 32, 426)  0          ['batch_normalization_48[0][0]',
#  ambda)                                                           'batch_normalization_49[0][0]']
#
#  activation_24 (Activation)     (None, 32, 32, 426)  0           ['tf.__operators__.add_12[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 32, 32, 426)  1704       ['activation_24[0][0]']
#  ormalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 426)  0          ['batch_normalization_50[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 142)  544428      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 16, 16, 142)  568        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 16, 16, 142)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 284)  362952      ['activation_26[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 16, 16, 284)  1136       ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 16, 16, 284)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 16, 16, 427)  1091412     ['activation_27[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 16, 16, 427)  1708       ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 16, 16, 427)  0           ['batch_normalization_56[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 853)  0           ['activation_26[0][0]',
#                                                                   'activation_27[0][0]',
#                                                                   'activation_28[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 16, 16, 853)  363378      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 16, 16, 853)  3412       ['concatenate_4[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 16, 16, 853)  3412       ['conv2d_39[0][0]']
#  ormalization)
#
#  conv2d_34 (Conv2D)             (None, 32, 32, 256)  981504      ['batch_normalization_50[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 256)  109056      ['batch_normalization_50[0][0]']
#
#  tf.__operators__.add_14 (TFOpL  (None, 16, 16, 853)  0          ['batch_normalization_57[0][0]',
#  ambda)                                                           'batch_normalization_58[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_34[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 16, 16, 853)  0           ['tf.__operators__.add_14[0][0]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 32, 32, 256)  0          ['batch_normalization_51[0][0]',
#  ambda)                                                           'batch_normalization_52[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 16, 16, 853)  3412       ['activation_29[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 32, 32, 256)  0           ['tf.__operators__.add_13[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 256)  873728     ['batch_normalization_59[0][0]']
#  ose)
#
#  batch_normalization_53 (BatchN  (None, 32, 32, 256)  1024       ['activation_25[0][0]']
#  ormalization)
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'batch_normalization_53[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 32, 32, 71)   327168      ['concatenate_5[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 32, 32, 71)  284         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 32, 32, 71)   0           ['batch_normalization_60[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 32, 32, 142)  90738       ['activation_30[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 32, 32, 142)  568        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 32, 32, 142)  0           ['batch_normalization_61[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 128)  244224      ['batch_normalization_38[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 128)  27136       ['batch_normalization_38[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 32, 32, 213)  272214      ['activation_31[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 64, 64, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 64, 64, 128)  512        ['conv2d_27[0][0]']
#  ormalization)
#
#  batch_normalization_62 (BatchN  (None, 32, 32, 213)  852        ['conv2d_42[0][0]']
#  ormalization)
#
#  tf.__operators__.add_10 (TFOpL  (None, 64, 64, 128)  0          ['batch_normalization_39[0][0]',
#  ambda)                                                           'batch_normalization_40[0][0]']
#
#  activation_32 (Activation)     (None, 32, 32, 213)  0           ['batch_normalization_62[0][0]']
#
#  activation_19 (Activation)     (None, 64, 64, 128)  0           ['tf.__operators__.add_10[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 32, 32, 426)  0           ['activation_30[0][0]',
#                                                                   'activation_31[0][0]',
#                                                                   'activation_32[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 32, 32, 426)  218112      ['concatenate_5[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 64, 64, 128)  512        ['activation_19[0][0]']
#  ormalization)
#
#  batch_normalization_63 (BatchN  (None, 32, 32, 426)  1704       ['concatenate_6[0][0]']
#  ormalization)
#
#  batch_normalization_64 (BatchN  (None, 32, 32, 426)  1704       ['conv2d_43[0][0]']
#  ormalization)
#
#  conv2d_28 (Conv2D)             (None, 64, 64, 128)  147456      ['batch_normalization_41[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 64, 64, 128)  16384       ['batch_normalization_41[0][0]']
#
#  tf.__operators__.add_15 (TFOpL  (None, 32, 32, 426)  0          ['batch_normalization_63[0][0]',
#  ambda)                                                           'batch_normalization_64[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 64, 64, 128)  512        ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 64, 64, 128)  512        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 32, 32, 426)  0           ['tf.__operators__.add_15[0][0]']
#
#  tf.__operators__.add_11 (TFOpL  (None, 64, 64, 128)  0          ['batch_normalization_42[0][0]',
#  ambda)                                                           'batch_normalization_43[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 32, 32, 426)  1704       ['activation_33[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 64, 64, 128)  0           ['tf.__operators__.add_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 128)  218240     ['batch_normalization_65[0][0]']
#  spose)
#
#  batch_normalization_44 (BatchN  (None, 64, 64, 128)  512        ['activation_20[0][0]']
#  ormalization)
#
#  concatenate_7 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'batch_normalization_44[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 64, 64, 35)   80640       ['concatenate_7[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 64  60480       ['batch_normalization_23[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 64  6720        ['batch_normalization_23[0][0]']
#                                 )
#
#  batch_normalization_66 (BatchN  (None, 64, 64, 35)  140         ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 128, 128, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  batch_normalization_25 (BatchN  (None, 128, 128, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_34 (Activation)     (None, 64, 64, 35)   0           ['batch_normalization_66[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 128, 128, 64  0          ['batch_normalization_24[0][0]',
#  mbda)                          )                                 'batch_normalization_25[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 64, 64, 71)   22365       ['activation_34[0][0]']
#
#  activation_12 (Activation)     (None, 128, 128, 64  0           ['tf.__operators__.add_6[0][0]']
#                                 )
#
#  batch_normalization_67 (BatchN  (None, 64, 64, 71)  284         ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 128, 128, 64  256        ['activation_12[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 64, 64, 71)   0           ['batch_normalization_67[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 64  36864       ['batch_normalization_26[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 128, 128, 64  4096        ['batch_normalization_26[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 64, 64, 106)  67734       ['activation_35[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 128, 128, 64  256        ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  batch_normalization_28 (BatchN  (None, 128, 128, 64  256        ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  batch_normalization_68 (BatchN  (None, 64, 64, 106)  424        ['conv2d_46[0][0]']
#  ormalization)
#
#  tf.__operators__.add_7 (TFOpLa  (None, 128, 128, 64  0          ['batch_normalization_27[0][0]',
#  mbda)                          )                                 'batch_normalization_28[0][0]']
#
#  activation_36 (Activation)     (None, 64, 64, 106)  0           ['batch_normalization_68[0][0]']
#
#  activation_13 (Activation)     (None, 128, 128, 64  0           ['tf.__operators__.add_7[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 64, 64, 212)  0           ['activation_34[0][0]',
#                                                                   'activation_35[0][0]',
#                                                                   'activation_36[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 64, 64, 212)  54272       ['concatenate_7[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 128, 128, 64  256        ['activation_13[0][0]']
#  ormalization)                  )
#
#  batch_normalization_69 (BatchN  (None, 64, 64, 212)  848        ['concatenate_8[0][0]']
#  ormalization)
#
#  batch_normalization_70 (BatchN  (None, 64, 64, 212)  848        ['conv2d_47[0][0]']
#  ormalization)
#
#  conv2d_20 (Conv2D)             (None, 128, 128, 64  36864       ['batch_normalization_29[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 64  4096        ['batch_normalization_29[0][0]']
#                                 )
#
#  tf.__operators__.add_16 (TFOpL  (None, 64, 64, 212)  0          ['batch_normalization_69[0][0]',
#  ambda)                                                           'batch_normalization_70[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 128, 128, 64  256        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  batch_normalization_31 (BatchN  (None, 128, 128, 64  256        ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 32  14688       ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 32  1632        ['batch_normalization_5[0][0]']
#                                 )
#
#  activation_37 (Activation)     (None, 64, 64, 212)  0           ['tf.__operators__.add_16[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 128, 128, 64  0          ['batch_normalization_30[0][0]',
#  mbda)                          )                                 'batch_normalization_31[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 256, 256, 32  128        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  batch_normalization_7 (BatchNo  (None, 256, 256, 32  128        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  batch_normalization_71 (BatchN  (None, 64, 64, 212)  848        ['activation_37[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 128, 128, 64  0           ['tf.__operators__.add_8[0][0]']
#                                 )
#
#  tf.__operators__.add_1 (TFOpLa  (None, 256, 256, 32  0          ['batch_normalization_6[0][0]',
#  mbda)                          )                                 'batch_normalization_7[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 64  54336      ['batch_normalization_71[0][0]']
#  spose)                         )
#
#  batch_normalization_32 (BatchN  (None, 128, 128, 64  256        ['activation_14[0][0]']
#  ormalization)                  )
#
#  activation_4 (Activation)      (None, 256, 256, 32  0           ['tf.__operators__.add_1[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_2[0][0]',
#                                 8)                                'batch_normalization_32[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 256, 256, 32  128        ['activation_4[0][0]']
#  rmalization)                   )
#
#  conv2d_48 (Conv2D)             (None, 128, 128, 17  19584       ['concatenate_9[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 256, 256, 32  9216        ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 256, 256, 32  1024        ['batch_normalization_8[0][0]']
#                                 )
#
#  batch_normalization_72 (BatchN  (None, 128, 128, 17  68         ['conv2d_48[0][0]']
#  ormalization)                  )
#
#  batch_normalization_9 (BatchNo  (None, 256, 256, 32  128        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  batch_normalization_10 (BatchN  (None, 256, 256, 32  128        ['conv2d_7[0][0]']
#  ormalization)                  )
#
#  activation_38 (Activation)     (None, 128, 128, 17  0           ['batch_normalization_72[0][0]']
#                                 )
#
#  tf.__operators__.add_2 (TFOpLa  (None, 256, 256, 32  0          ['batch_normalization_9[0][0]',
#  mbda)                          )                                 'batch_normalization_10[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 128, 128, 35  5355        ['activation_38[0][0]']
#                                 )
#
#  activation_5 (Activation)      (None, 256, 256, 32  0           ['tf.__operators__.add_2[0][0]']
#                                 )
#
#  batch_normalization_73 (BatchN  (None, 128, 128, 35  140        ['conv2d_49[0][0]']
#  ormalization)                  )
#
#  batch_normalization_11 (BatchN  (None, 256, 256, 32  128        ['activation_5[0][0]']
#  ormalization)                  )
#
#  activation_39 (Activation)     (None, 128, 128, 35  0           ['batch_normalization_73[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 256, 256, 32  9216        ['batch_normalization_11[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 256, 256, 32  1024        ['batch_normalization_11[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 128, 128, 53  16695       ['activation_39[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 256, 256, 32  128        ['conv2d_8[0][0]']
#  ormalization)                  )
#
#  batch_normalization_13 (BatchN  (None, 256, 256, 32  128        ['conv2d_9[0][0]']
#  ormalization)                  )
#
#  batch_normalization_74 (BatchN  (None, 128, 128, 53  212        ['conv2d_50[0][0]']
#  ormalization)                  )
#
#  tf.__operators__.add_3 (TFOpLa  (None, 256, 256, 32  0          ['batch_normalization_12[0][0]',
#  mbda)                          )                                 'batch_normalization_13[0][0]']
#
#  activation_40 (Activation)     (None, 128, 128, 53  0           ['batch_normalization_74[0][0]']
#                                 )
#
#  activation_6 (Activation)      (None, 256, 256, 32  0           ['tf.__operators__.add_3[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 128, 128, 10  0           ['activation_38[0][0]',
#                                 5)                                'activation_39[0][0]',
#                                                                   'activation_40[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 128, 128, 10  13440       ['concatenate_9[0][0]']
#                                 5)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 32  128        ['activation_6[0][0]']
#  ormalization)                  )
#
#  batch_normalization_75 (BatchN  (None, 128, 128, 10  420        ['concatenate_10[0][0]']
#  ormalization)                  5)
#
#  batch_normalization_76 (BatchN  (None, 128, 128, 10  420        ['conv2d_51[0][0]']
#  ormalization)                  5)
#
#  conv2d_10 (Conv2D)             (None, 256, 256, 32  9216        ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 256, 256, 32  1024        ['batch_normalization_14[0][0]']
#                                 )
#
#  tf.__operators__.add_17 (TFOpL  (None, 128, 128, 10  0          ['batch_normalization_75[0][0]',
#  ambda)                         5)                                'batch_normalization_76[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 32  128        ['conv2d_10[0][0]']
#  ormalization)                  )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 32  128        ['conv2d_11[0][0]']
#  ormalization)                  )
#
#  activation_41 (Activation)     (None, 128, 128, 10  0           ['tf.__operators__.add_17[0][0]']
#                                 5)
#
#  tf.__operators__.add_4 (TFOpLa  (None, 256, 256, 32  0          ['batch_normalization_15[0][0]',
#  mbda)                          )                                 'batch_normalization_16[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 128, 128, 10  420        ['activation_41[0][0]']
#  ormalization)                  5)
#
#  activation_7 (Activation)      (None, 256, 256, 32  0           ['tf.__operators__.add_4[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 32  13472      ['batch_normalization_77[0][0]']
#  spose)                         )
#
#  batch_normalization_17 (BatchN  (None, 256, 256, 32  128        ['activation_7[0][0]']
#  ormalization)                  )
#
#  concatenate_11 (Concatenate)   (None, 256, 256, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'batch_normalization_17[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 256, 256, 8)  4608        ['concatenate_11[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 256, 256, 8)  32         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 256, 256, 8)  0           ['batch_normalization_78[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 256, 256, 17  1224        ['activation_42[0][0]']
#                                 )
#
#  batch_normalization_79 (BatchN  (None, 256, 256, 17  68         ['conv2d_53[0][0]']
#  ormalization)                  )
#
#  activation_43 (Activation)     (None, 256, 256, 17  0           ['batch_normalization_79[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 256, 256, 26  3978        ['activation_43[0][0]']
#                                 )
#
#  batch_normalization_80 (BatchN  (None, 256, 256, 26  104        ['conv2d_54[0][0]']
#  ormalization)                  )
#
#  activation_44 (Activation)     (None, 256, 256, 26  0           ['batch_normalization_80[0][0]']
#                                 )
#
#  concatenate_12 (Concatenate)   (None, 256, 256, 51  0           ['activation_42[0][0]',
#                                 )                                 'activation_43[0][0]',
#                                                                   'activation_44[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 256, 256, 51  3264        ['concatenate_11[0][0]']
#                                 )
#
#  batch_normalization_81 (BatchN  (None, 256, 256, 51  204        ['concatenate_12[0][0]']
#  ormalization)                  )
#
#  batch_normalization_82 (BatchN  (None, 256, 256, 51  204        ['conv2d_55[0][0]']
#  ormalization)                  )
#
#  tf.__operators__.add_18 (TFOpL  (None, 256, 256, 51  0          ['batch_normalization_81[0][0]',
#  ambda)                         )                                 'batch_normalization_82[0][0]']
#
#  activation_45 (Activation)     (None, 256, 256, 51  0           ['tf.__operators__.add_18[0][0]']
#                                 )
#
#  batch_normalization_83 (BatchN  (None, 256, 256, 51  204        ['activation_45[0][0]']
#  ormalization)                  )
#
#  conv2d_56 (Conv2D)             (None, 256, 256, 4)  208         ['batch_normalization_83[0][0]']
#
# ==================================================================================================
# Total params: 7,269,450
# Trainable params: 7,244,930
# Non-trainable params: 24,520
# __________________________________________________________________________________________________

# %%
import os

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision, Accuracy, IoU
from sklearn.model_selection import train_test_split

H = 256
W = 256

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive_path = '/content/drive/MyDrive/PFA'

# %%
def create_dir(path): #TO BE CHANGED
    """Create a directory"""
    if not os.path.exists(path):
        os.mkdir(path)

# %%
def load_data(path, split=0.2):

    images = sorted(glob(f"{path}/ROI/*.bmp"))
    masks = sorted(glob(f"{path}/label/*.bmp"))
    
    print(len(masks), len(images))

    train_x, valid_x = train_test_split(images, test_size=0.2, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=0.2, random_state=42)
    print(len(train_x), len(train_y), len(valid_x), len(valid_y))
   
    return (train_x, train_y), (valid_x, valid_y)

# %%
def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = x / 255.0
    x = x.astype(np.float32)
    return x

# %%
def read_mask(path):
    path = path.decode('utf-8')
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x[x == 255] = 0
    x[x == 223] = 1 #ZP
    x[x == 127] = 2 #TE
    x[x == 191] = 3 #ICM
    x[ x > 3] = 0
    x = x.astype(np.int32)
    return x

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.int32])
    y = tf.one_hot(y, 4, dtype=tf.int32)
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 4])

    return x, y

# %%
def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.shuffle(buffer_size=5000)
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.repeat()
    dataset = dataset.prefetch(2)

    return dataset

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

"""Directory for storing files"""
create_dir("/content/drive/MyDrive/PFA/files_multiresunet")

"""Hyperparameters"""
batch_size = 10
learning_rate = 1e-4
num_epochs = 30
model_path = os.path.join("/content/drive/MyDrive/PFA/files_multiresunet", "model.h5")
csv_path = os.path.join("/content/drive/MyDrive/PFA/files_multiresunet", "data.csv")

"""Dataset"""
dataset_path = os.path.join("/content/drive/MyDrive/PFA/new_data")
train_path = os.path.join(dataset_path, "train")

(train_x, train_y), (valid_x, valid_y) = load_data(train_path)


print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch=batch_size)

test_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

"""Model"""

model = build_multiresunet((256, 256, 3),4)

metrics = [dice_coef, iou, 'accuracy', Recall(), Precision()]
model.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate), metrics=metrics)

train_steps = len(train_x)//batch_size
valid_steps = len(valid_x)//batch_size

callbacks = [
  ModelCheckpoint(model_path, verbose=1, save_best_only=True),
  ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-7, verbose=1),
  CSVLogger(csv_path),
  TensorBoard(),
  EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=False)
]

history = model.fit(
        train_dataset,
        steps_per_epoch=train_steps,
        epochs=num_epochs,
        validation_data=test_dataset,
        validation_steps=valid_steps,
        callbacks=callbacks
    )
# Out:
# 945 945
# 756 756 189 189
# Train: 756 - 756
# Valid: 189 - 189
# Epoch 1/30
# 75/75 [==============================] - ETA: 0s - loss: 1.1528 - dice_coef: 0.4951 - iou: 0.3348 - accuracy: 0.6581 - recall: 0.5612 - precision: 0.7200
# Epoch 1: val_loss improved from inf to 1.35579, saving model to /content/drive/MyDrive/PFA/files_multiresunet/model.h5
# 75/75 [==============================] - 513s 6s/step - loss: 1.1528 - dice_coef: 0.4951 - iou: 0.3348 - accuracy: 0.6581 - recall: 0.5612 - precision: 0.7200 - val_loss: 1.3558 - val_dice_coef: 0.2676 - val_iou: 0.1545 - val_accuracy: 0.1413 - val_recall: 5.9340e-06 - val_precision: 0.0020 - lr: 1.0000e-04
# Epoch 2/30
# 75/75 [==============================] - ETA: 0s - loss: 0.6196 - dice_coef: 0.6851 - iou: 0.5216 - accuracy: 0.8498 - recall: 0.8127 - precision: 0.8840
# Epoch 2: val_loss improved from 1.35579 to 1.13488, saving model to /content/drive/MyDrive/PFA/files_multiresunet/model.h5
# 75/75 [==============================] - 116s 1s/step - loss: 0.6196 - dice_coef: 0.6851 - iou: 0.5216 - accuracy: 0.8498 - recall: 0.8127 - precision: 0.8840 - val_loss: 1.1349 - val_dice_coef: 0.3534 - val_iou: 0.2146 - val_accuracy: 0.6503 - val_recall: 0.0433 - val_precision: 0.7453 - lr: 1.0000e-04
# Epoch 3/30
# 75/75 [==============================] - ETA: 0s - loss: 0.4620 - dice_coef: 0.7492 - iou: 0.5994 - accuracy: 0.8840 - recall: 0.8588 - precision: 0.9052
# Epoch 3: val_loss improved from 1.13488 to 1.02619, saving model to /content/drive/MyDrive/PFA/files_multiresunet/model.h5
# 75/75 [==============================] - 104s 1s/step - loss: 0.4620 - dice_coef: 0.7492 - iou: 0.5994 - accuracy: 0.8840 - recall: 0.8588 - precision: 0.9052 - val_loss: 1.0262 - val_dice_coef: 0.4647 - val_iou: 0.3028 - val_accuracy: 0.6742 - val_recall: 0.6556 - val_precision: 0.6783 - lr: 1.0000e-04
# Epoch 4/30
# 75/75 [==============================] - ETA: 0s - loss: 0.3575 - dice_coef: 0.7973 - iou: 0.6631 - accuracy: 0.9030 - recall: 0.8869 - precision: 0.9166
# Epoch 4: val_loss improved from 1.02619 to 0.85594, saving model to /content/drive/MyDrive/PFA/files_multiresunet/model.h5
# 75/75 [==============================] - 104s 1s/step - loss: 0.3575 - dice_coef: 0.7973 - iou: 0.6631 - accuracy: 0.9030 - recall: 0.8869 - precision: 0.9166 - val_loss: 0.8559 - val_dice_coef: 0.5869 - val_iou: 0.4157 - val_accuracy: 0.7180 - val_recall: 0.7072 - val_precision: 0.7302 - lr: 1.0000e-04
# Epoch 5/30
# 75/75 [==============================] - ETA: 0s - loss: 0.2903 - dice_coef: 0.8290 - iou: 0.7080 - accuracy: 0.9145 - recall: 0.9029 - precision: 0.9245
# Epoch 5: val_loss improved from 0.85594 to 0.67479, saving model to /content/drive/MyDrive/PFA/files_multiresunet/model.h5
# 75/75 [==============================] - 104s 1s/step - loss: 0.2903 - dice_coef: 0.8290 - iou: 0.7080 - accuracy: 0.9145 - recall: 0.9029 - precision: 0.9245 - val_loss: 0.6748 - val_dice_coef: 0.7340 - val_iou: 0.5800 - val_accuracy: 0.7969 - val_recall: 0.7769 - val_precision: 0.8113 - lr: 1.0000e-04
# Epoch 6/30
# 75/75 [==============================] - ETA: 0s - loss: 0.2429 - dice_coef: 0.8537 - iou: 0.7449 - accuracy: 0.9246 - recall: 0.9161 - precision: 0.9320
# Epoch 6: val_loss improved from 0.67479 to 0.57033, saving model to /content/drive/MyDrive/PFA/files_multiresunet/model.h5
# 75/75 [==============================] - 107s 1s/step - loss: 0.2429 - dice_coef: 0.8537 - iou: 0.7449 - accuracy: 0.9246 - recall: 0.9161 - precision: 0.9320 - val_loss: 0.5703 - val_dice_coef: 0.8034 - val_iou: 0.6714 - val_accuracy: 0.8588 - val_recall: 0.8458 - val_precision: 0.8698 - lr: 1.0000e-04
# Epoch 7/30
# 75/75 [==============================] - ETA: 0s - loss: 0.2071 - dice_coef: 0.8742 - iou: 0.7767 - accuracy: 0.9344 - recall: 0.9281 - precision: 0.9399
# Epoch 7: val_loss improved from 0.57033 to 0.41912, saving model to /content/drive/MyDrive/PFA/files_multiresunet/model.h5
# 75/75 [==============================] - 107s 1s/step - loss: 0.2071 - dice_coef: 0.8742 - iou: 0.7767 - accuracy: 0.9344 - recall: 0.9281 - precision: 0.9399 - val_loss: 0.4191 - val_dice_coef: 0.8342 - val_iou: 0.7157 - val_accuracy: 0.8850 - val_recall: 0.8772 - val_precision: 0.8920 - lr: 1.0000e-04
# Epoch 8/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1717 - dice_coef: 0.8933 - iou: 0.8073 - accuracy: 0.9431 - recall: 0.9384 - precision: 0.9472
# Epoch 8: val_loss improved from 0.41912 to 0.38775, saving model to /content/drive/MyDrive/PFA/files_multiresunet/model.h5
# 75/75 [==============================] - 104s 1s/step - loss: 0.1717 - dice_coef: 0.8933 - iou: 0.8073 - accuracy: 0.9431 - recall: 0.9384 - precision: 0.9472 - val_loss: 0.3877 - val_dice_coef: 0.8471 - val_iou: 0.7349 - val_accuracy: 0.8891 - val_recall: 0.8833 - val_precision: 0.8940 - lr: 1.0000e-04
# Epoch 9/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1512 - dice_coef: 0.9066 - iou: 0.8292 - accuracy: 0.9492 - recall: 0.9456 - precision: 0.9524
# Epoch 9: val_loss did not improve from 0.38775
# 75/75 [==============================] - 105s 1s/step - loss: 0.1512 - dice_coef: 0.9066 - iou: 0.8292 - accuracy: 0.9492 - recall: 0.9456 - precision: 0.9524 - val_loss: 0.4007 - val_dice_coef: 0.8580 - val_iou: 0.7514 - val_accuracy: 0.8924 - val_recall: 0.8882 - val_precision: 0.8961 - lr: 1.0000e-04
# Epoch 10/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1388 - dice_coef: 0.9142 - iou: 0.8420 - accuracy: 0.9523 - recall: 0.9494 - precision: 0.9550
# Epoch 10: val_loss did not improve from 0.38775
# 75/75 [==============================] - 102s 1s/step - loss: 0.1388 - dice_coef: 0.9142 - iou: 0.8420 - accuracy: 0.9523 - recall: 0.9494 - precision: 0.9550 - val_loss: 0.4138 - val_dice_coef: 0.8705 - val_iou: 0.7707 - val_accuracy: 0.8993 - val_recall: 0.8962 - val_precision: 0.9021 - lr: 1.0000e-04
# Epoch 11/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1296 - dice_coef: 0.9198 - iou: 0.8516 - accuracy: 0.9550 - recall: 0.9525 - precision: 0.9573
# Epoch 11: val_loss did not improve from 0.38775
# 75/75 [==============================] - 105s 1s/step - loss: 0.1296 - dice_coef: 0.9198 - iou: 0.8516 - accuracy: 0.9550 - recall: 0.9525 - precision: 0.9573 - val_loss: 0.5185 - val_dice_coef: 0.8681 - val_iou: 0.7672 - val_accuracy: 0.8942 - val_recall: 0.8911 - val_precision: 0.8971 - lr: 1.0000e-04
# Epoch 12/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1165 - dice_coef: 0.9274 - iou: 0.8647 - accuracy: 0.9591 - recall: 0.9571 - precision: 0.9609
# Epoch 12: val_loss improved from 0.38775 to 0.38204, saving model to /content/drive/MyDrive/PFA/files_multiresunet/model.h5
# 75/75 [==============================] - 107s 1s/step - loss: 0.1165 - dice_coef: 0.9274 - iou: 0.8647 - accuracy: 0.9591 - recall: 0.9571 - precision: 0.9609 - val_loss: 0.3820 - val_dice_coef: 0.8718 - val_iou: 0.7729 - val_accuracy: 0.8944 - val_recall: 0.8925 - val_precision: 0.8960 - lr: 1.0000e-04
# Epoch 13/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1057 - dice_coef: 0.9342 - iou: 0.8765 - accuracy: 0.9620 - recall: 0.9604 - precision: 0.9636
# Epoch 13: val_loss did not improve from 0.38204
# 75/75 [==============================] - 105s 1s/step - loss: 0.1057 - dice_coef: 0.9342 - iou: 0.8765 - accuracy: 0.9620 - recall: 0.9604 - precision: 0.9636 - val_loss: 0.4222 - val_dice_coef: 0.8733 - val_iou: 0.7753 - val_accuracy: 0.8939 - val_recall: 0.8922 - val_precision: 0.8953 - lr: 1.0000e-04
# Epoch 14/30
# 75/75 [==============================] - ETA: 0s - loss: 0.1021 - dice_coef: 0.9370 - iou: 0.8814 - accuracy: 0.9631 - recall: 0.9616 - precision: 0.9644
# Epoch 14: val_loss improved from 0.38204 to 0.37562, saving model to /content/drive/MyDrive/PFA/files_multiresunet/model.h5
# 75/75 [==============================] - 104s 1s/step - loss: 0.1021 - dice_coef: 0.9370 - iou: 0.8814 - accuracy: 0.9631 - recall: 0.9616 - precision: 0.9644 - val_loss: 0.3756 - val_dice_coef: 0.8754 - val_iou: 0.7786 - val_accuracy: 0.8956 - val_recall: 0.8942 - val_precision: 0.8968 - lr: 1.0000e-04
# Epoch 15/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0963 - dice_coef: 0.9405 - iou: 0.8878 - accuracy: 0.9650 - recall: 0.9637 - precision: 0.9663
# Epoch 15: val_loss did not improve from 0.37562
# 75/75 [==============================] - 105s 1s/step - loss: 0.0963 - dice_coef: 0.9405 - iou: 0.8878 - accuracy: 0.9650 - recall: 0.9637 - precision: 0.9663 - val_loss: 0.5559 - val_dice_coef: 0.8663 - val_iou: 0.7643 - val_accuracy: 0.8813 - val_recall: 0.8800 - val_precision: 0.8824 - lr: 1.0000e-04
# Epoch 16/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0987 - dice_coef: 0.9392 - iou: 0.8854 - accuracy: 0.9633 - recall: 0.9621 - precision: 0.9644
# Epoch 16: val_loss did not improve from 0.37562
# 75/75 [==============================] - 102s 1s/step - loss: 0.0987 - dice_coef: 0.9392 - iou: 0.8854 - accuracy: 0.9633 - recall: 0.9621 - precision: 0.9644 - val_loss: 0.4037 - val_dice_coef: 0.8872 - val_iou: 0.7973 - val_accuracy: 0.9046 - val_recall: 0.9034 - val_precision: 0.9057 - lr: 1.0000e-04
# Epoch 17/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0856 - dice_coef: 0.9468 - iou: 0.8990 - accuracy: 0.9681 - recall: 0.9671 - precision: 0.9691
# Epoch 17: val_loss did not improve from 0.37562
# 75/75 [==============================] - 105s 1s/step - loss: 0.0856 - dice_coef: 0.9468 - iou: 0.8990 - accuracy: 0.9681 - recall: 0.9671 - precision: 0.9691 - val_loss: 0.4072 - val_dice_coef: 0.8851 - val_iou: 0.7941 - val_accuracy: 0.9003 - val_recall: 0.8994 - val_precision: 0.9011 - lr: 1.0000e-04
# Epoch 18/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0845 - dice_coef: 0.9477 - iou: 0.9007 - accuracy: 0.9685 - recall: 0.9675 - precision: 0.9694
# Epoch 18: val_loss did not improve from 0.37562
# 75/75 [==============================] - 102s 1s/step - loss: 0.0845 - dice_coef: 0.9477 - iou: 0.9007 - accuracy: 0.9685 - recall: 0.9675 - precision: 0.9694 - val_loss: 0.4292 - val_dice_coef: 0.8871 - val_iou: 0.7971 - val_accuracy: 0.9014 - val_recall: 0.9004 - val_precision: 0.9023 - lr: 1.0000e-04
# Epoch 19/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0821 - dice_coef: 0.9496 - iou: 0.9041 - accuracy: 0.9694 - recall: 0.9685 - precision: 0.9702
# Epoch 19: val_loss did not improve from 0.37562
# 75/75 [==============================] - 105s 1s/step - loss: 0.0821 - dice_coef: 0.9496 - iou: 0.9041 - accuracy: 0.9694 - recall: 0.9685 - precision: 0.9702 - val_loss: 0.4534 - val_dice_coef: 0.8898 - val_iou: 0.8015 - val_accuracy: 0.9033 - val_recall: 0.9023 - val_precision: 0.9041 - lr: 1.0000e-04
# Epoch 20/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0799 - dice_coef: 0.9511 - iou: 0.9067 - accuracy: 0.9697 - recall: 0.9689 - precision: 0.9704
# Epoch 20: val_loss did not improve from 0.37562
# 75/75 [==============================] - 105s 1s/step - loss: 0.0799 - dice_coef: 0.9511 - iou: 0.9067 - accuracy: 0.9697 - recall: 0.9689 - precision: 0.9704 - val_loss: 0.4805 - val_dice_coef: 0.8938 - val_iou: 0.8081 - val_accuracy: 0.9061 - val_recall: 0.9052 - val_precision: 0.9069 - lr: 1.0000e-04
# Epoch 21/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0775 - dice_coef: 0.9524 - iou: 0.9092 - accuracy: 0.9707 - recall: 0.9700 - precision: 0.9714
# Epoch 21: val_loss did not improve from 0.37562
# 75/75 [==============================] - 102s 1s/step - loss: 0.0775 - dice_coef: 0.9524 - iou: 0.9092 - accuracy: 0.9707 - recall: 0.9700 - precision: 0.9714 - val_loss: 0.4228 - val_dice_coef: 0.8895 - val_iou: 0.8012 - val_accuracy: 0.9010 - val_recall: 0.9004 - val_precision: 0.9016 - lr: 1.0000e-04
# Epoch 22/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0809 - dice_coef: 0.9511 - iou: 0.9068 - accuracy: 0.9690 - recall: 0.9683 - precision: 0.9697
# Epoch 22: val_loss did not improve from 0.37562
# 75/75 [==============================] - 105s 1s/step - loss: 0.0809 - dice_coef: 0.9511 - iou: 0.9068 - accuracy: 0.9690 - recall: 0.9683 - precision: 0.9697 - val_loss: 0.6835 - val_dice_coef: 0.8683 - val_iou: 0.7673 - val_accuracy: 0.8808 - val_recall: 0.8798 - val_precision: 0.8816 - lr: 1.0000e-04
# Epoch 23/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0773 - dice_coef: 0.9524 - iou: 0.9091 - accuracy: 0.9703 - recall: 0.9696 - precision: 0.9709
# Epoch 23: val_loss did not improve from 0.37562
# 75/75 [==============================] - 102s 1s/step - loss: 0.0773 - dice_coef: 0.9524 - iou: 0.9091 - accuracy: 0.9703 - recall: 0.9696 - precision: 0.9709 - val_loss: 0.4680 - val_dice_coef: 0.8866 - val_iou: 0.7964 - val_accuracy: 0.8973 - val_recall: 0.8967 - val_precision: 0.8978 - lr: 1.0000e-04
# Epoch 24/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0699 - dice_coef: 0.9568 - iou: 0.9172 - accuracy: 0.9729 - recall: 0.9723 - precision: 0.9735
# Epoch 24: val_loss did not improve from 0.37562
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 75/75 [==============================] - 105s 1s/step - loss: 0.0699 - dice_coef: 0.9568 - iou: 0.9172 - accuracy: 0.9729 - recall: 0.9723 - precision: 0.9735 - val_loss: 0.4776 - val_dice_coef: 0.8943 - val_iou: 0.8089 - val_accuracy: 0.9051 - val_recall: 0.9044 - val_precision: 0.9057 - lr: 1.0000e-04
# Epoch 25/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0631 - dice_coef: 0.9597 - iou: 0.9226 - accuracy: 0.9760 - recall: 0.9755 - precision: 0.9765
# Epoch 25: val_loss did not improve from 0.37562
# 75/75 [==============================] - 101s 1s/step - loss: 0.0631 - dice_coef: 0.9597 - iou: 0.9226 - accuracy: 0.9760 - recall: 0.9755 - precision: 0.9765 - val_loss: 0.4355 - val_dice_coef: 0.8965 - val_iou: 0.8126 - val_accuracy: 0.9069 - val_recall: 0.9063 - val_precision: 0.9074 - lr: 1.0000e-05
# Epoch 26/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0599 - dice_coef: 0.9614 - iou: 0.9258 - accuracy: 0.9769 - recall: 0.9764 - precision: 0.9774
# Epoch 26: val_loss did not improve from 0.37562
# 75/75 [==============================] - 104s 1s/step - loss: 0.0599 - dice_coef: 0.9614 - iou: 0.9258 - accuracy: 0.9769 - recall: 0.9764 - precision: 0.9774 - val_loss: 0.4355 - val_dice_coef: 0.8981 - val_iou: 0.8151 - val_accuracy: 0.9082 - val_recall: 0.9077 - val_precision: 0.9088 - lr: 1.0000e-05
# Epoch 27/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0572 - dice_coef: 0.9628 - iou: 0.9284 - accuracy: 0.9782 - recall: 0.9776 - precision: 0.9786
# Epoch 27: val_loss did not improve from 0.37562
# 75/75 [==============================] - 102s 1s/step - loss: 0.0572 - dice_coef: 0.9628 - iou: 0.9284 - accuracy: 0.9782 - recall: 0.9776 - precision: 0.9786 - val_loss: 0.4541 - val_dice_coef: 0.8972 - val_iou: 0.8137 - val_accuracy: 0.9071 - val_recall: 0.9065 - val_precision: 0.9076 - lr: 1.0000e-05
# Epoch 28/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0584 - dice_coef: 0.9629 - iou: 0.9284 - accuracy: 0.9774 - recall: 0.9769 - precision: 0.9779
# Epoch 28: val_loss did not improve from 0.37562
# 75/75 [==============================] - 101s 1s/step - loss: 0.0584 - dice_coef: 0.9629 - iou: 0.9284 - accuracy: 0.9774 - recall: 0.9769 - precision: 0.9779 - val_loss: 0.4552 - val_dice_coef: 0.8984 - val_iou: 0.8157 - val_accuracy: 0.9080 - val_recall: 0.9074 - val_precision: 0.9085 - lr: 1.0000e-05
# Epoch 29/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0553 - dice_coef: 0.9644 - iou: 0.9312 - accuracy: 0.9790 - recall: 0.9785 - precision: 0.9794
# Epoch 29: val_loss did not improve from 0.37562
# 75/75 [==============================] - 101s 1s/step - loss: 0.0553 - dice_coef: 0.9644 - iou: 0.9312 - accuracy: 0.9790 - recall: 0.9785 - precision: 0.9794 - val_loss: 0.4599 - val_dice_coef: 0.8977 - val_iou: 0.8145 - val_accuracy: 0.9070 - val_recall: 0.9065 - val_precision: 0.9075 - lr: 1.0000e-05
# Epoch 30/30
# 75/75 [==============================] - ETA: 0s - loss: 0.0582 - dice_coef: 0.9639 - iou: 0.9304 - accuracy: 0.9779 - recall: 0.9774 - precision: 0.9784
# Epoch 30: val_loss did not improve from 0.37562
# 75/75 [==============================] - 101s 1s/step - loss: 0.0582 - dice_coef: 0.9639 - iou: 0.9304 - accuracy: 0.9779 - recall: 0.9774 - precision: 0.9784 - val_loss: 0.4750 - val_dice_coef: 0.8972 - val_iou: 0.8136 - val_accuracy: 0.9064 - val_recall: 0.9059 - val_precision: 0.9069 - lr: 1.0000e-05

# %%
# Plot the chart for accuracy and loss on both training and validation
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training precision')
plt.plot(epochs, val_acc, 'b', label='Validation precision')
plt.title('Training and validation precision')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
def load_data(path):

    images = sorted(glob(f"{path}/ROI/*.bmp"))
    masks = sorted(glob(f"{path}/label/*.bmp"))
    
    print(len(images), len(masks))
   
    return (images, masks)

# %%
test_path = os.path.join(dataset_path, "test")
(test_x, test_y) = load_data(test_path)
# Out:
# 48 48

# %%
from tqdm import tqdm

# %%
num_classes = 4

# %%
res_path = os.path.join(dataset_path, "results_multiresunet")
create_dir(res_path)
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
        name = x.split("/")[-1]

        ## Read image
        
        x = cv2.imread(x, cv2.IMREAD_COLOR)
        x = x / 255.0
        x = x.astype(np.float32)

        ## Read mask
        y = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
        y[y == 255] = 0
        y[y == 223] = 1 #ZP
        y[y == 127] = 2 #TE
        y[y == 191] = 3 #ICM
        y[ y > 3] = 0
        y = np.expand_dims(y, axis=-1) ## (256, 256, 1)
        y = y * (255/num_classes)
        y = y.astype(np.int32)
        y = np.concatenate([y, y, y], axis=2)

        ## Prediction
        p = model.predict(np.expand_dims(x, axis=0))[0]
        p = np.argmax(p, axis=-1)
        p = np.expand_dims(p, axis=-1)
        p = p * (255/num_classes)
        p = p.astype(np.int32)
        p = np.concatenate([p, p, p], axis=2)

        x = x * 255.0
        x = x.astype(np.int32)

        h, w, _ = x.shape
        line = np.ones((h, 10, 3)) * 255

        print(x.shape, line.shape, y.shape, line.shape, p.shape)

        final_image = np.concatenate([x, line, y, line, p], axis=1)
        status = cv2.imwrite(f"{res_path}/{name}", final_image)
        print(status)
# Out:
#   2%|▏         | 1/48 [00:07<05:32,  7.08s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#   4%|▍         | 2/48 [00:08<02:52,  3.75s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#   6%|▋         | 3/48 [00:09<02:00,  2.68s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#   8%|▊         | 4/48 [00:11<01:37,  2.22s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  10%|█         | 5/48 [00:12<01:24,  1.96s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  12%|█▎        | 6/48 [00:14<01:14,  1.78s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  15%|█▍        | 7/48 [00:16<01:14,  1.81s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  17%|█▋        | 8/48 [00:17<01:08,  1.72s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  19%|█▉        | 9/48 [00:19<01:03,  1.63s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  21%|██        | 10/48 [00:20<00:57,  1.51s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  23%|██▎       | 11/48 [00:21<00:51,  1.40s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  25%|██▌       | 12/48 [00:22<00:50,  1.40s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  27%|██▋       | 13/48 [00:24<00:49,  1.42s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  29%|██▉       | 14/48 [00:26<00:49,  1.47s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  31%|███▏      | 15/48 [00:27<00:46,  1.40s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  33%|███▎      | 16/48 [00:28<00:46,  1.47s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  35%|███▌      | 17/48 [00:30<00:45,  1.47s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  38%|███▊      | 18/48 [00:31<00:41,  1.38s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  40%|███▉      | 19/48 [00:33<00:41,  1.43s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  42%|████▏     | 20/48 [00:34<00:40,  1.45s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  44%|████▍     | 21/48 [00:36<00:39,  1.47s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  46%|████▌     | 22/48 [00:37<00:38,  1.47s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  48%|████▊     | 23/48 [00:39<00:36,  1.46s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  50%|█████     | 24/48 [00:40<00:36,  1.51s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  52%|█████▏    | 25/48 [00:42<00:34,  1.49s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  54%|█████▍    | 26/48 [00:43<00:31,  1.42s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  56%|█████▋    | 27/48 [00:44<00:28,  1.38s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  58%|█████▊    | 28/48 [00:46<00:28,  1.42s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  60%|██████    | 29/48 [00:47<00:27,  1.43s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  62%|██████▎   | 30/48 [00:49<00:25,  1.44s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  65%|██████▍   | 31/48 [00:50<00:24,  1.45s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  67%|██████▋   | 32/48 [00:52<00:23,  1.46s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  69%|██████▉   | 33/48 [00:53<00:21,  1.46s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  71%|███████   | 34/48 [00:54<00:20,  1.48s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  73%|███████▎  | 35/48 [00:56<00:19,  1.53s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  75%|███████▌  | 36/48 [00:58<00:18,  1.51s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  77%|███████▋  | 37/48 [00:59<00:16,  1.50s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  79%|███████▉  | 38/48 [01:01<00:14,  1.50s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  81%|████████▏ | 39/48 [01:02<00:13,  1.48s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  83%|████████▎ | 40/48 [01:03<00:11,  1.48s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  85%|████████▌ | 41/48 [01:05<00:10,  1.48s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  88%|████████▊ | 42/48 [01:06<00:08,  1.40s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  90%|████████▉ | 43/48 [01:08<00:07,  1.43s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  92%|█████████▏| 44/48 [01:09<00:06,  1.51s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  94%|█████████▍| 45/48 [01:11<00:04,  1.51s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  96%|█████████▌| 46/48 [01:12<00:02,  1.44s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
#  98%|█████████▊| 47/48 [01:14<00:01,  1.50s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
# 100%|██████████| 48/48 [01:15<00:00,  1.58s/it]
# (256, 256, 3) (256, 10, 3) (256, 256, 3) (256, 10, 3) (256, 256, 3)
# True
