# %%
import os
import cv2
from glob import glob
import numpy as np
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from albumentations import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import csv
from google.colab.patches import cv2_imshow

# %%
def read_this(image_file):
   
    image_src = cv2.imread(image_file,cv2.IMREAD_GRAYSCALE)
    
    return image_src

# %%
drive_path = '/content/drive/MyDrive/PFA/new_data/train' 

images ="/content/drive/MyDrive/PFA/new_data/train/images/Blast_PCRM_R16-0437B_0.bmp"
masks_full = "/content/drive/MyDrive/PFA/new_data/train/GT_full/Blast_PCRM_R16-0437B full_0.bmp"
masks_zp = "/content/drive/MyDrive/PFA/new_data/train/GT_ZP/Blast_PCRM_R16-0437B ZP_Mask_0.bmp"  

img=read_this(images)
zp=read_this(masks_zp)
full=read_this(masks_full)

#cv2_imshow(img)
#cv2_imshow(zp)
#cv2_imshow(full)

# %%
zp[zp!=0]=255
image=cv2.add(zp,full)
cv2_imshow(image)
print(img)
i= image * img
cv2_imshow(i)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FFBAE2D8F50>
# [[214 210 210 ... 214 210 214]
#  [210 210 210 ... 219 196 210]
#  [214 210 214 ... 205 210 214]
#  ...
#  [200 196 205 ... 186 196 210]
#  [205 186 210 ... 191 205 191]
#  [196 196 191 ... 186 200 196]]
# <PIL.Image.Image image mode=L size=256x256 at 0x7FFBAE3458D0>

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FFBAE3254D0>
