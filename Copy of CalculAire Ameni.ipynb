# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
from google.colab import drive
drive.mount('/content/drive')
drive_path = '/content/drive/MyDrive/PFA'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = os.path.join("/content/drive/MyDrive/PFA/single_resnet50/Blast_PCRM_R12-0221b ROI.bmp")

# %%
import cv2

y=cv2.imread(path, cv2.IMREAD_GRAYSCALE)
print(y.shape)
# Out:
# (256, 256)

# %%
import csv
pathcsv = os.path.join("/content/drive/MyDrive/PFA/new_data/real_size.csv")
filecsv = open(pathcsv)

# %%
def load_img(path):
    s = f"{path}"
    return (s)

# %%
s=load_img(path)

# %%
y=cv2.imread(s, cv2.IMREAD_GRAYSCALE)
print(y.shape)
# Out:
# (256, 256)

# %%
csvreader = csv.reader(filecsv)
rows = []
for row in csvreader:
    rows.append(row)

print(rows)
nb=len(rows) # nb ofimages = of 

for r in rows:
    name=r[0]#name of image
    h=r[1]#height
    w=r[2]#width

elem='Blast_PCRM_R12-0221b.bmp'
#remember: new data file names have 'ROI' in them
#either sort both files when reading 
#(sort elems of csv and images of newdat> results_resnet50 )
# or find common string

i=0
pos=0
for row in rows:
  if row[0]==elem:
    pos=i
    break
  i=i+1

original_height= int(rows[pos][1])
original_width= int(rows[pos][2])
# Out:
# [['Blast_PCRM_R14-0186.bmp', '406', '468'], ['Blast_PCRM_1202591 D5.bmp', '396', '468'], ['Blast_PCRM_R13-0235a.bmp', '398', '505'], ['Blast_PCRM_R13-0014A.bmp', '350', '470'], ['Blast_PCRM_R13-0385b.bmp', '402', '435'], ['Blast_PCRM_R16-0037a.bmp', '413', '458'], ['Blast_PCRM_R16-0157a.bmp', '417', '504'], ['Blast_PCRM_R16-0075a.bmp', '382', '509'], ['Blast_PCRM_1202833 D5.bmp', '421', '433'], ['Blast_PCRM_R13-0309b.bmp', '382', '389'], ['Blast_PCRM_R16-0195A.bmp', '465', '516'], ['Blast_PCRM_R16-0276A.bmp', '436', '539'], ['Blast_PCRM_R16-0199A.bmp', '406', '506'], ['Blast_PCRM_d5.bmp', '339', '384'], ['Blast_PCRM_R13-0044.bmp', '315', '372'], ['Blast_PCRM_R16-0344A.bmp', '384', '471'], ['Blast_PCRM_R16-0138a.bmp', '418', '523'], ['Blast_PCRM_R12-0160.bmp', '356', '401'], ['Blast_PCRM_R14-0369a.bmp', '401', '498'], ['Blast_PCRM_R12-0259.bmp', '418', '494'], ['Blast_PCRM_d5.bmp', '378', '424'], ['Blast_PCRM_R12-0221b.bmp', '408', '474'], ['Blast_PCRM_R13-0410a.bmp', '395', '443'], ['Blast_PCRM_R13-0051A.bmp', '385', '407'], ['Blast_PCRM_R14-0411a.bmp', '416', '491'], ['Blast_PCRM_R12-0397b.bmp', '376', '521'], ['Blast_PCRM_R13-0006A.bmp', '292', '358'], ['Blast_PCRM_1202834 D5.bmp', '390', '437'], ['Blast_PCRM_R12-0306a.bmp', '355', '502'], ['Blast_PCRM_R13-0524.bmp', '321', '351'], ['Blast_PCRM_R16-0198A.bmp', '390', '495'], ['Blast_PCRM_R12-0316a.bmp', '393', '469
313', '368'], ['Blast_PCRM_R13-0036B_2.bmp', '313', '368'], ['Blast_PCRM_R13-0036B_3.bmp', '368', '313'], ['Blast_PCRM_R13-0036B_4.bmp', '368', '313'], ['Blast_PCRM_R16-0294A_0.bmp', '370', '471'], ['Blast_PCRM_R16-0294A_1.bmp', '370', '471'], ['Blast_PCRM_R16-0294A_2.bmp', '370', '471'], ['Blast_PCRM_R16-0294A_3.bmp', '471', '370'], ['Blast_PCRM_R16-0294A_4.bmp', '471', '370'], ['Blast_PCRM_R14-0348a_0.bmp', '4 ...

# %%
import numpy as np

# %%
def feature(img,val):
  
  #I'm only constructing the image in case we need perimeter (contour detection) or something later
  
  area=0
  for x in range(h):
    for y in range(w):
      if img[x,y]==val:
        
        area+=1#nb pixels
      
  return area

# %%
print(y.shape)
imagef = cv2.resize(y, (original_width, original_height), interpolation = cv2.INTER_NEAREST)
print(imagef.shape)
# Out:
# (256, 256)
# (408, 474)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(imagef)
#gives different values in image
# Out:
# <PIL.Image.Image image mode=L size=474x408 at 0x7F06FF6BA310>

# %%
#this part just shows the nb of pixels with a specific colour
colours, counts = np.unique(imagef.reshape(-1,1), axis=0, return_counts=1)
# Iterate through unique colours
for index, colour in enumerate(colours):
    count = counts[index]
    print(f"   Colour: {colour}, count: {count}")
# Out:
#    Colour: [0], count: 125040
#    Colour: [63], count: 31270
#    Colour: [127], count: 17707
#    Colour: [191], count: 19375

# %%
cv2_imshow(imagef)
# Out:
# <PIL.Image.Image image mode=L size=474x408 at 0x7F06FF597710>

# %%
circles = cv2.HoughCircles(imagef,cv2.HOUGH_GRADIENT, 1, 100, param1= 100, param2=20, minRadius=110, maxRadius=220)
circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(imagef,(i[0],i[1]),i[2],(255,255,255),2)
    # draw the center of the circle
    cv2.circle(imagef,(i[0],i[1]),2,(255,255,255),3)
cv2_imshow(imagef)
print(circles)
# Out:
# <PIL.Image.Image image mode=L size=474x408 at 0x7F06FF5ACF10>
# [[[226 194 202]]]

# %%
h=imagef.shape[0]
w=imagef.shape[1]

# %%
h_c=h//2
w_c=w//2
pixel_centree=(h_c,w_c)

# %%
height=0
radius=0
nb=0
while (height<=h_c) :
    if imagef[height,w_c]!=0 :
      radius=radius+1
    height=height+1

# %%
width=0
zp_right=0
while(width<=w_c) :
  if imagef[h_c,width]==63 :
      zp_right=zp_right+1
  width=width+1

# %%
width=w_c
zp_left=0
while(width<w) :
  if imagef[h_c,width]==63 :
      zp_left=zp_left+1
  width=width+1

# %%
height=0
zp_high=0

while (height<=h_c) :
    if imagef[height,w_c]==63 :
      zp_high=zp_high+1
    height=height+1

# %%
height=h_c
zp_down=0

while (height<h) :
    if imagef[height,w_c]==63 :
      zp_down=zp_down+1
    height=height+1

# %%
zp_thickness=(zp_down+zp_high+zp_right+zp_left)/4

# %%
zp_thickness
# Out:
# 30.5

# %%
radius
# Out:
# 103
